# %%
pip install -r ../requirement.txt
# Out:
# Requirement already satisfied: pandas==2.2.3 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirement.txt (line 1)) (2.2.3)
# Requirement already satisfied: openpyxl in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirement.txt (line 2)) (3.1.5)
# Requirement already satisfied: matplotlib in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirement.txt (line 3)) (3.10.3)
# Requirement already satisfied: seaborn in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirement.txt (line 4)) (0.13.2)
# Requirement already satisfied: scipy in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirement.txt (line 5)) (1.15.3)
# Requirement already satisfied: numpy>=1.23.2 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from pandas==2.2.3->-r ../requirement.txt (line 1)) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from pandas==2.2.3->-r ../requirement.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from pandas==2.2.3->-r ../requirement.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from pandas==2.2.3->-r ../requirement.txt (line 1)) (2025.2)
# Requirement already satisfied: et-xmlfile in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from openpyxl->-r ../requirement.txt (line 2)) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirement.txt (line 3)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirement.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirement.txt (line 3)) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirement.txt (line 3)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirement.txt (line 3)) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirement.txt (line 3)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirement.txt (line 3)) (3.2.3)
# Requirement already satisfied: six>=1.5 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->-r ../requirement.txt (line 1)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# pd.set_option('display.float_format', '{:.6f}'.format)
# Mostrar todas las columnas sin límite
pd.set_option('display.max_columns', None)

# %%
# Leer el archivo CSV
productos_df = pd.read_csv('productos.zip', sep='|')

productos_df.head()
# Out:
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_98749/2831869706.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   productos_df = pd.read_csv('productos.zip', sep='|')
#   id_comercio  id_bandera  id_sucursal   id_producto  productos_ean  \
# 0          10         1.0         63.0  7.790771e+12            1.0
# 1          10         3.0        711.0  7.790070e+12            1.0
# 2          10         1.0         44.0  7.622202e+12            1.0
# 3          10         2.0         62.0  7.791293e+12            1.0
# 4          10         1.0          2.0  7.791720e+12            1.0
#
#                                productos_descripcion  \
# 0         TOALLA NOSOTRAS CLASICAS C CALENDULA X 16U
# 1         FIDEOS DEDALITOS LUCCHETTI BOLSA X 500 GRS
# 2        GALLETITAS BOCA DE DAMA TERRABUSI X 170 GRS
# 3  ACONDICIONADOR LISO EFECTO BOTOX TRESEMME X 25...
# 4             ANANA EN RODAJAS BULNEZ LATA X 825 GRS
#
#    productos_cantidad_presentacion productos_unidad_medida_presentacion  \
# 0                              1.0                                  UNI
# 1                              1.0                                  UNI
# 2                              1.0                                  UNI
# 3                              1.0                                  UNI
# 4                              1.0                                  UNI
#
#   productos_marca  productos_precio_lista  productos_precio_referencia  \
# 0        NOSOTRAS                  2809.0                       175.56
# 1       LUCCHETTI                  1339.0                      2678.00
# 2       TERRABUSI                   959.0                      5641.18
# 3        TRESEMME                  3969.0                     15876.00
# 4          BULNEZ                  2990.0                      3624.24
#
#    productos_cantidad_referencia productos_unidad_medida_referencia  \
# 0                           16.0                                UNI
# 1                          500.0                                GRM
# 2                          170.0                                GRM
# 3                          250.0                                CM3
# 4                          825.0                                GRM
#
#    productos_precio_unitario_promo1 productos_leyenda_promo1  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
#
#    productos_precio_unitario_promo2  productos_leyenda_promo2
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN

# %%
productos_df.dtypes
# Out:
# id_comercio                              object
# id_bandera                              float64
# id_sucursal                             float64
# id_producto                             float64
# productos_ean                           float64
# productos_descripcion                    object
# productos_cantidad_presentacion         float64
# productos_unidad_medida_presentacion     object
# productos_marca                          object
# productos_precio_lista                  float64
# productos_precio_referencia             float64
# productos_cantidad_referencia           float64
# productos_unidad_medida_referencia       object
# productos_precio_unitario_promo1        float64
# productos_leyenda_promo1                 object
# productos_precio_unitario_promo2        float64
# productos_leyenda_promo2                float64
# dtype: object

# %%
productos_df.describe()
# Out:
#          id_bandera   id_sucursal   id_producto  productos_ean  \
# count  2.232853e+06  2.232853e+06  2.232853e+06   2.232853e+06
# mean   2.065017e+00  3.166739e+02  7.322620e+12   9.777025e-01
# std    8.728486e-01  2.318601e+02  1.653917e+12   1.476493e-01
# min    1.000000e+00  1.000000e+00  4.008140e+07   0.000000e+00
# 25%    1.000000e+00  1.370000e+02  7.790315e+12   1.000000e+00
# 50%    2.000000e+00  2.560000e+02  7.791720e+12   1.000000e+00
# 75%    3.000000e+00  4.960000e+02  7.794521e+12   1.000000e+00
# max    3.000000e+00  8.100000e+02  9.002490e+12   1.000000e+00
#
#        productos_cantidad_presentacion  productos_precio_lista  \
# count                        2232853.0            2.232853e+06
# mean                               1.0            1.050002e+04
# std                                0.0            8.212710e+04
# min                                1.0            3.600000e+01
# 25%                                1.0            1.619000e+03
# 50%                                1.0            2.790000e+03
# 75%                                1.0            5.099000e+03
# max                                1.0            7.349000e+06
#
#        productos_precio_referencia  productos_cantidad_referencia  \
# count                 2.232853e+06                   2.232853e+06
# mean                  2.112866e+04                   3.965329e+02
# std                   9.270248e+04                   5.130412e+02
# min                   2.700000e-01                   0.000000e+00
# 25%                   3.610000e+03                   8.500000e+01
# 50%                   8.350000e+03                   2.370000e+02
# 75%                   1.695000e+04                   5.000000e+02
# max                   7.349000e+06                   8.000000e+03
#
#        productos_precio_unitario_promo1  productos_precio_unitario_promo2  \
# count                      6.870200e+04                               0.0
# mean                       6.686930e+04                               NaN
# std                        2.463596e+05                               NaN
# min                        4.500000e+01                               NaN
# 25%                        1.290000e+03                               NaN
# 50%                        1.990000e+03                               NaN
# 75%                        4.500000e+03                               NaN
# max                        6.849000e+06                               NaN
#
#        productos_leyenda_promo2
# count                       0.0
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN

# %%
productos_df.tail()
# Out:
#                                              id_comercio  id_bandera  \
# 2232849                                               10         2.0
# 2232850                                               10         3.0
# 2232851                                               10         3.0
# 2232852                                               10         3.0
# 2232853  Ultima actualización: 2025-05-02T05:00:43-03:00         NaN
#
#          id_sucursal   id_producto  productos_ean  \
# 2232849        512.0  2.509067e+12            0.0
# 2232850        736.0  7.790010e+12            1.0
# 2232851        748.0  7.730908e+12            1.0
# 2232852        450.0  7.790070e+12            1.0
# 2232853          NaN           NaN            NaN
#
#                                     productos_descripcion  \
# 2232849                        QUESO CREMOSO FRACC SILVIA
# 2232850  ACOND HIDRATACION INTENSA JOHNSONS KIDS X 200 CC
# 2232851        JUGO EN POLVO MIX FRUTAL RINDE DOS X 13GRS
# 2232852   FIDEOS INTEGRALES SPAGHETTI MATARAZZO X 500 GRS
# 2232853                                               NaN
#
#          productos_cantidad_presentacion productos_unidad_medida_presentacion  \
# 2232849                              1.0                                  KGM
# 2232850                              1.0                                  UNI
# 2232851                              1.0                                  UNI
# 2232852                              1.0                                  UNI
# 2232853                              NaN                                  NaN
#
#         productos_marca  productos_precio_lista  productos_precio_referencia  \
# 2232849             S/D                 14359.0                      14359.0
# 2232850   JOHNSONS BABY                  4965.0                      24825.0
# 2232851       RINDE DOS                   559.0                       4300.0
# 2232852       MATARAZZO                  2009.0                       4018.0
# 2232853             NaN                     NaN                          NaN
#
#          productos_cantidad_referencia productos_unidad_medida_referencia  \
# 2232849                         1000.0                                GRM
# 2232850                          200.0                                CM3
# 2232851                           13.0                                GRS
# 2232852                          500.0                                GRM
# 2232853                            NaN                                NaN
#
#          productos_precio_unitario_promo1  \
# 2232849                             790.0
# 2232850                            2310.0
# 2232851                               NaN
# 2232852                               NaN
# 2232853                               NaN
#
#                                   productos_leyenda_promo1  \
# 2232849  Promo A valida desde el 02/05/2025 hasta 04/05...
# 2232850  Promo A valida desde el 17/04/2025 hasta 20/05...
# 2232851                                                NaN
# 2232852                                                NaN
# 2232853                                                NaN
#
#          productos_precio_unitario_promo2  productos_leyenda_promo2
# 2232849                               NaN                       NaN
# 2232850                               NaN                       NaN
# 2232851                               NaN                       NaN
# 2232852                               NaN                       NaN
# 2232853                               NaN                       NaN

# %%
#notamos que el ultimo registro de cada csv es irrelevante
productos_df = productos_df.drop(productos_df.index[-1])

# %%
productos_df.isnull().sum()
# Out:
# id_comercio                                   0
# id_bandera                                    0
# id_sucursal                                   0
# id_producto                                   0
# productos_ean                                 0
# productos_descripcion                         0
# productos_cantidad_presentacion               0
# productos_unidad_medida_presentacion          0
# productos_marca                               0
# productos_precio_lista                        0
# productos_precio_referencia                   0
# productos_cantidad_referencia                 0
# productos_unidad_medida_referencia            0
# productos_precio_unitario_promo1        2164151
# productos_leyenda_promo1                2164151
# productos_precio_unitario_promo2        2232853
# productos_leyenda_promo2                2232853
# dtype: int64

# %%
len(productos_df)
# Out:
# 2232853

# %%
productos_df.columns
# Out:
# Index(['id_comercio', 'id_bandera', 'id_sucursal', 'id_producto',
#        'productos_ean', 'productos_descripcion',
#        'productos_cantidad_presentacion',
#        'productos_unidad_medida_presentacion', 'productos_marca',
#        'productos_precio_lista', 'productos_precio_referencia',
#        'productos_cantidad_referencia', 'productos_unidad_medida_referencia',
#        'productos_precio_unitario_promo1', 'productos_leyenda_promo1',
#        'productos_precio_unitario_promo2', 'productos_leyenda_promo2'],
#       dtype='object')

# %%
# verificamos cuantos registros tienen el codigo de producto EAN y cuantos no
productos_df['productos_ean'].value_counts()
# Out:
# productos_ean
# 1.0    2183066
# 0.0      49787
# Name: count, dtype: int64

# %%
productos_df['productos_ean'].duplicated().sum()
# Out:
# np.int64(2232851)

# %%
#Verificamos que no haya un id_producto repetido como ean y como NO ean
mask = productos_df.groupby('id_producto')['productos_ean'].nunique() > 1

# Filtrar el DataFrame original con los valores que cumplen la condición
df_filtrado = productos_df[productos_df['id_producto'].isin(mask[mask].index)]
df_filtrado.head()
# Out:
# Empty DataFrame
# Columns: [id_comercio, id_bandera, id_sucursal, id_producto, productos_ean, productos_descripcion, productos_cantidad_presentacion, productos_unidad_medida_presentacion, productos_marca, productos_precio_lista, productos_precio_referencia, productos_cantidad_referencia, productos_unidad_medida_referencia, productos_precio_unitario_promo1, productos_leyenda_promo1, productos_precio_unitario_promo2, productos_leyenda_promo2]
# Index: []

# %%
columnas_de_interes = [ 
       'id_sucursal',
       'id_producto',
       'productos_ean',
       'productos_descripcion',
       'productos_cantidad_presentacion',
       'productos_unidad_medida_presentacion',
       'productos_marca',
       'productos_precio_lista',
       'productos_precio_referencia',
       'productos_cantidad_referencia',
       'productos_unidad_medida_referencia',
       'productos_precio_unitario_promo1',
       'productos_leyenda_promo1',
       'productos_precio_unitario_promo2',
       'productos_leyenda_promo2'
]

# %%
productos_df = productos_df[columnas_de_interes]
productos_df.head()
# Out:
#    id_sucursal   id_producto  productos_ean  \
# 0         63.0  7.790771e+12            1.0
# 1        711.0  7.790070e+12            1.0
# 2         44.0  7.622202e+12            1.0
# 3         62.0  7.791293e+12            1.0
# 4          2.0  7.791720e+12            1.0
#
#                                productos_descripcion  \
# 0         TOALLA NOSOTRAS CLASICAS C CALENDULA X 16U
# 1         FIDEOS DEDALITOS LUCCHETTI BOLSA X 500 GRS
# 2        GALLETITAS BOCA DE DAMA TERRABUSI X 170 GRS
# 3  ACONDICIONADOR LISO EFECTO BOTOX TRESEMME X 25...
# 4             ANANA EN RODAJAS BULNEZ LATA X 825 GRS
#
#    productos_cantidad_presentacion productos_unidad_medida_presentacion  \
# 0                              1.0                                  UNI
# 1                              1.0                                  UNI
# 2                              1.0                                  UNI
# 3                              1.0                                  UNI
# 4                              1.0                                  UNI
#
#   productos_marca  productos_precio_lista  productos_precio_referencia  \
# 0        NOSOTRAS                  2809.0                       175.56
# 1       LUCCHETTI                  1339.0                      2678.00
# 2       TERRABUSI                   959.0                      5641.18
# 3        TRESEMME                  3969.0                     15876.00
# 4          BULNEZ                  2990.0                      3624.24
#
#    productos_cantidad_referencia productos_unidad_medida_referencia  \
# 0                           16.0                                UNI
# 1                          500.0                                GRM
# 2                          170.0                                GRM
# 3                          250.0                                CM3
# 4                          825.0                                GRM
#
#    productos_precio_unitario_promo1 productos_leyenda_promo1  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
#
#    productos_precio_unitario_promo2  productos_leyenda_promo2
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN

# %%
productos_df['id_sucursal'] = productos_df['id_sucursal'].astype(int)
productos_df['productos_ean'] = productos_df['productos_ean'].astype(int).astype(bool)
productos_df['id_producto'] = productos_df['id_producto'].astype(int).astype(str)
productos_df['productos_unidad_medida_presentacion'] = productos_df['productos_unidad_medida_presentacion'].astype('category')
productos_df['productos_marca'] = productos_df['productos_marca'].astype('category')
productos_df['productos_unidad_medida_referencia'] = productos_df['productos_unidad_medida_referencia'].astype('category')
productos_df['precio_zscore'] = productos_df.groupby('id_producto')['productos_precio_referencia'].transform(
    lambda x: (x - x.mean()) / x.std()
)
productos_df = productos_df[productos_df['productos_descripcion'].str.contains('yerba', case=False, na=False)]
productos_df.head()
# Out:
#      id_sucursal    id_producto  productos_ean  \
# 164          175  7793670000670           True
# 228          436  7790710334573           True
# 247          472  7791720036976           True
# 259          638  7790070509109           True
# 380          530  7790387013627           True
#
#                                 productos_descripcion  \
# 164          YERBA MATE CON MENTA VERDEFLOR X 500 GRS
# 228       YERBA MATE CON HIERBAS SERRANAS CBSE X 1 KG
# 247  YERBA MATE C PALO SUAVE CARREFOUR CLASSIC X 500G
# 259         YERBA MATE SUAVE NOBLEZA GAUCHA X 500 GRS
# 380    YERBA MATE C PALO ORIG CONTROL TARAGUI X 500 G
#
#      productos_cantidad_presentacion productos_unidad_medida_presentacion  \
# 164                              1.0                                  UNI
# 228                              1.0                                  UNI
# 247                              1.0                                  UNI
# 259                              1.0                                  UNI
# 380                              1.0                                  UNI
#
#        productos_marca  productos_precio_lista  productos_precio_referencia  \
# 164          VERDEFLOR                  2150.0                       4300.0
# 228               CBSE                  3545.0                       3545.0
# 247  CARREFOUR CLASSIC                  2050.0                       4100.0
# 259     NOBLEZA GAUCHA                  1695.0                       3390.0
# 380            TARAGUI                  2035.0                       4070.0
#
#      productos_cantidad_referencia productos_unidad_medida_referencia  \
# 164                          500.0                                GRM
# 228                         1000.0                                GRM
# 247                          500.0                                GRM
# 259                          500.0                                GRM
# 380                          500.0                                GRM
#
#      productos_precio_unitario_promo1 productos_leyenda_promo1  \
# 164                               NaN                      NaN
# 228                               NaN                      NaN
# 247                               NaN                      NaN
# 259                               NaN                      NaN
# 380                               NaN                      NaN
#
#      productos_precio_unitario_promo2  productos_leyenda_promo2  precio_zscore
# 164                               NaN                       NaN       1.233785
# 228                               NaN                       NaN       0.162049
# 247                               NaN                       NaN      -0.186079
# 259                               NaN                       NaN      -0.315001
# 380                               NaN                       NaN      -0.276920

# %%
productos_df["id_producto"].nunique()
# Out:
# 135

# %%
productos_df["id_producto"].value_counts()
# Out:
# id_producto
# 7790387014624    566
# 7790387013610    566
# 7791720024751    566
# 7790387014617    566
# 7791720026335    566
#                 ...
# 758890928040       5
# 7730241009038      3
# 7730241009113      3
# 7730241003654      2
# 7730241003715      1
# Name: count, Length: 135, dtype: int64

# %% [markdown]
# De la ultima celda podemos analizar que hay productos que estan en TODAS las sucursales y que hay productos que no

# %%
# Leer el archivo Excel
sucursales_df = pd.read_excel('../sucursales/sucursales_procesado.xlsx')
sucursales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id_bandera               567 non-null    int64
#  1   id_sucursal              567 non-null    int64
#  2   sucursales_nombre        567 non-null    object
#  3   sucursales_tipo          567 non-null    object
#  4   sucursales_latitud       567 non-null    float64
#  5   sucursales_longitud      567 non-null    float64
#  6   sucursales_barrio        303 non-null    object
#  7   sucursales_localidad     567 non-null    object
#  8   sucursales_provincia     567 non-null    object
#  9   comercio_bandera_nombre  567 non-null    object
#  10  localidad_provincia      567 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 48.9+ KB

# %%
#Uno los dataframe por la columna de id_sucursal
df_completo = pd.merge(productos_df, sucursales_df, on='id_sucursal', how='left')
df_completo.head()
# Out:
#    id_sucursal    id_producto  productos_ean  \
# 0          175  7793670000670           True
# 1          436  7790710334573           True
# 2          472  7791720036976           True
# 3          638  7790070509109           True
# 4          530  7790387013627           True
#
#                               productos_descripcion  \
# 0          YERBA MATE CON MENTA VERDEFLOR X 500 GRS
# 1       YERBA MATE CON HIERBAS SERRANAS CBSE X 1 KG
# 2  YERBA MATE C PALO SUAVE CARREFOUR CLASSIC X 500G
# 3         YERBA MATE SUAVE NOBLEZA GAUCHA X 500 GRS
# 4    YERBA MATE C PALO ORIG CONTROL TARAGUI X 500 G
#
#    productos_cantidad_presentacion productos_unidad_medida_presentacion  \
# 0                              1.0                                  UNI
# 1                              1.0                                  UNI
# 2                              1.0                                  UNI
# 3                              1.0                                  UNI
# 4                              1.0                                  UNI
#
#      productos_marca  productos_precio_lista  productos_precio_referencia  \
# 0          VERDEFLOR                  2150.0                       4300.0
# 1               CBSE                  3545.0                       3545.0
# 2  CARREFOUR CLASSIC                  2050.0                       4100.0
# 3     NOBLEZA GAUCHA                  1695.0                       3390.0
# 4            TARAGUI                  2035.0                       4070.0
#
#    productos_cantidad_referencia productos_unidad_medida_referencia  \
# 0                          500.0                                GRM
# 1                         1000.0                                GRM
# 2                          500.0                                GRM
# 3                          500.0                                GRM
# 4                          500.0                                GRM
#
#    productos_precio_unitario_promo1 productos_leyenda_promo1  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
#
#    productos_precio_unitario_promo2  productos_leyenda_promo2  precio_zscore  \
# 0                               NaN                       NaN       1.233785
# 1                               NaN                       NaN       0.162049
# 2                               NaN                       NaN      -0.186079
# 3                               NaN                       NaN      -0.315001
# 4                               NaN                       NaN      -0.276920
#
#    id_bandera sucursales_nombre sucursales_tipo  sucursales_latitud  \
# 0           1         Salta VII    Hipermercado          -24.779652
# 1           3       Paraná 6543    Autoservicio          -34.525713
# 2           3    Jauretche 1125    Autoservicio          -34.589617
# 3           3   Av. de Mayo 432    Autoservicio          -34.490709
# 4           3    Rivadavia 6074    Autoservicio          -34.624687
#
#    sucursales_longitud sucursales_barrio             sucursales_localidad  \
# 0           -65.427437               NaN                            Salta
# 1           -58.548663               NaN                    Villa Adelina
# 2           -58.632800               NaN                       Hurlingham
# 3           -58.843137               NaN                           Derqui
# 4           -58.451248         Caballito  Ciudad Autónoma de Buenos Aires
#
#   sucursales_provincia comercio_bandera_nombre  \
# 0                Salta  Hipermercado Carrefour
# 1         Buenos Aires                 Express
# 2         Buenos Aires                 Express
# 3         Buenos Aires                 Express
# 4                 CABA                 Express
#
#                       localidad_provincia
# 0                           Salta - Salta
# 1            Villa Adelina - Buenos Aires
# 2               Hurlingham - Buenos Aires
# 3                   Derqui - Buenos Aires
# 4  Ciudad Autónoma de Buenos Aires - CABA

# %%
# Vamos a analizar las sucursales que son del tipo supermercado
completo_supermercado_df = df_completo[
    (df_completo['sucursales_provincia'] == 'Buenos Aires') | 
    (df_completo['sucursales_provincia'] == 'CABA')
]
completo_supermercado_df = completo_supermercado_df[completo_supermercado_df['sucursales_tipo'] == 'Supermercado']
completo_supermercado_df.head()
# Out:
#     id_sucursal    id_producto  productos_ean  \
# 5           109  7790710334641           True
# 12          134  7790387014624           True
# 18          226  7790070509109           True
# 21          115  7790710334641           True
# 25          195  7798067630010           True
#
#                                 productos_descripcion  \
# 5   YERBA MATE SILUETA NARNJA CBSE CORMILLOT X 500...
# 12       YERBA MATE SUAVE ORIG CONTROL UNION X 500GRS
# 18          YERBA MATE SUAVE NOBLEZA GAUCHA X 500 GRS
# 21  YERBA MATE SILUETA NARNJA CBSE CORMILLOT X 500...
# 25                  YERBA COMPUESTA ARREGUI X 500 GRS
#
#     productos_cantidad_presentacion productos_unidad_medida_presentacion  \
# 5                               1.0                                  UNI
# 12                              1.0                                  UNI
# 18                              1.0                                  UNI
# 21                              1.0                                  UNI
# 25                              1.0                                  UNI
#
#    productos_marca  productos_precio_lista  productos_precio_referencia  \
# 5             CBSE                  1699.0                       3398.0
# 12           UNION                  2500.0                       5000.0
# 18  NOBLEZA GAUCHA                  1645.0                       3290.0
# 21            CBSE                  1699.0                       3398.0
# 25         ARREGUI                  1600.0                       3200.0
#
#     productos_cantidad_referencia productos_unidad_medida_referencia  \
# 5                           500.0                                GRM
# 12                          500.0                                GRM
# 18                          500.0                                GRM
# 21                          500.0                                GRM
# 25                          500.0                                GRM
#
#     productos_precio_unitario_promo1  \
# 5                                NaN
# 12                               NaN
# 18                               NaN
# 21                               NaN
# 25                            1450.0
#
#                              productos_leyenda_promo1  \
# 5                                                 NaN
# 12                                                NaN
# 18                                                NaN
# 21                                                NaN
# 25  Promo A valida desde el 01/05/2025 hasta 30/05...
#
#     productos_precio_unitario_promo2  productos_leyenda_promo2  precio_zscore  \
# 5                                NaN                       NaN      -1.484866
# 12                               NaN                       NaN      -0.263978
# 18                               NaN                       NaN      -0.663624
# 21                               NaN                       NaN      -1.484866
# 25                               NaN                       NaN      -0.263702
#
#     id_bandera  sucursales_nombre sucursales_tipo  sucursales_latitud  \
# 5            2         La Plata I    Supermercado          -34.913497
# 12           2          Tandil II    Supermercado          -37.326474
# 18           2  Martínez (Edison)    Supermercado          -34.492689
# 21           2             Flores    Supermercado          -34.627423
# 25           2           Olazabal    Supermercado          -34.574379
#
#     sucursales_longitud sucursales_barrio             sucursales_localidad  \
# 5            -57.951821               NaN                         La Plata
# 12           -59.135087               NaN                           Tandil
# 18           -58.499192               NaN                         Martínez
# 21           -58.458170               NaN  Ciudad Autónoma de Buenos Aires
# 25           -58.482128               NaN  Ciudad Autónoma de Buenos Aires
#
#    sucursales_provincia comercio_bandera_nombre  \
# 5          Buenos Aires                  Market
# 12         Buenos Aires                  Market
# 18         Buenos Aires                  Market
# 21                 CABA                  Market
# 25                 CABA                  Market
#
#                        localidad_provincia
# 5                  La Plata - Buenos Aires
# 12                   Tandil - Buenos Aires
# 18                 Martínez - Buenos Aires
# 21  Ciudad Autónoma de Buenos Aires - CABA
# 25  Ciudad Autónoma de Buenos Aires - CABA

# %%
# Contar el número de sucursales únicas por producto
productos_en_todas_sucursales = completo_supermercado_df.groupby('id_producto')['comercio_bandera_nombre'].nunique()

# Filtrar los productos que están en todas los comercios, que en nuestro caso son 3, expres, hiper, market
productos_en_todas_sucursales = productos_en_todas_sucursales[productos_en_todas_sucursales == 3].index

# Filtrar el DataFrame original
productos_df_en_varias_sucursales = completo_supermercado_df[completo_supermercado_df['id_producto'].isin(productos_en_todas_sucursales)]
print(f"Cantidad de productos que estan en los 3 comercios {len(productos_df_en_varias_sucursales['id_producto'].value_counts())}")
productos_df_en_varias_sucursales["id_producto"].value_counts()
# Out:
# Cantidad de productos que estan en los 3 comercios 50
# id_producto
# 7792280005693    77
# 7792280005709    77
# 7791720024768    77
# 7791720026335    77
# 7790387013634    77
# 7790387014624    77
# 7791720024751    77
# 7790387015317    77
# 7791720024775    77
# 7791720032305    77
# 7790387013610    77
# 7791720024782    77
# 7790070509109    77
# 7790387014617    76
# 7790387013627    76
# 7792280005754    76
# 7791720036969    76
# 7792710000182    76
# 7790387014631    76
# 7790387014136    76
# 7790070509123    76
# 7793704000911    76
# 7790387014143    76
# 7790387015324    76
# 7790480089734    76
# 7790387015607    76
# 7790710334535    75
# 7793704000928    75
# 7791720036976    75
# 7792710000175    75
# 7793323024572    75
# 7790710334641    74
# 7790070509055    74
# 7790070507389    73
# 7793670000052    72
# 7790387013504    62
# 7790070509048    57
# 7790070507273    56
# 7790387800197    56
# 7792280005730    56
# 7792280005686    55
# 7792710006443    55
# 7790387015614    55
# 7790070509017    55
# 7790070507280    55
# 7793670000014    55
# 7790387013498    54
# 7790387015621    54
# 7792710006436    54
# 7792280005761    52
# Name: count, dtype: int64

# %%
# Agrupar por id_producto y comercio_bandera_nombre y calcular el máximo y mínimo de precio_zscore
resultado = productos_df_en_varias_sucursales.groupby(['id_producto', 'comercio_bandera_nombre'])['precio_zscore'].agg(['max', 'min']).reset_index()

resultado["id_producto"].value_counts()
# Out:
# id_producto
# 7790070507273    3
# 7792280005709    3
# 7791720024751    3
# 7791720024768    3
# 7791720024775    3
# 7791720024782    3
# 7791720026335    3
# 7791720032305    3
# 7791720036969    3
# 7791720036976    3
# 7792280005686    3
# 7792280005693    3
# 7792280005730    3
# 7790070507280    3
# 7792280005754    3
# 7792280005761    3
# 7792710000175    3
# 7792710000182    3
# 7792710006436    3
# 7792710006443    3
# 7793323024572    3
# 7793670000014    3
# 7793670000052    3
# 7793704000911    3
# 7790710334641    3
# 7790710334535    3
# 7790480089734    3
# 7790387800197    3
# 7790070507389    3
# 7790070509017    3
# 7790070509048    3
# 7790070509055    3
# 7790070509109    3
# 7790070509123    3
# 7790387013498    3
# 7790387013504    3
# 7790387013610    3
# 7790387013627    3
# 7790387013634    3
# 7790387014136    3
# 7790387014143    3
# 7790387014617    3
# 7790387014624    3
# 7790387014631    3
# 7790387015317    3
# 7790387015324    3
# 7790387015607    3
# 7790387015614    3
# 7790387015621    3
# 7793704000928    3
# Name: count, dtype: int64

# %%
resultado.head()
# Out:
#      id_producto comercio_bandera_nombre       max       min
# 0  7790070507273                 Express  1.331063  1.331063
# 1  7790070507273  Hipermercado Carrefour -0.772474 -0.772474
# 2  7790070507273                  Market  1.331063 -1.209157
# 3  7790070507280                 Express -0.061380 -0.061380
# 4  7790070507280  Hipermercado Carrefour -1.067405 -1.067405

# %%
# Ordenar el DataFrame por la columna 'id_producto'
resultado = resultado.sort_values(by='max').reset_index(drop=True)

# Convertir la columna 'id_producto' a categórica
resultado['id_producto'] = resultado['id_producto'].astype('category')

# Agregar una nueva columna con el código numérico de la categoría
resultado['id_producto_code'] = resultado['id_producto'].cat.codes

resultado.head(20)
# Out:
#       id_producto comercio_bandera_nombre       max       min  \
# 0   7792280005754  Hipermercado Carrefour -2.621061 -2.621061
# 1   7790070507389  Hipermercado Carrefour -2.262921 -2.262921
# 2   7790070509055  Hipermercado Carrefour -1.878333 -1.878333
# 3   7792280005709  Hipermercado Carrefour -1.862547 -1.862547
# 4   7790710334535  Hipermercado Carrefour -1.596318 -1.596318
# 5   7790710334641  Hipermercado Carrefour -1.484866 -1.484866
# 6   7790070509048  Hipermercado Carrefour -1.095735 -1.095735
# 7   7790070507280  Hipermercado Carrefour -1.067405 -1.067405
# 8   7792710006443  Hipermercado Carrefour -1.051409 -1.051409
# 9   7790070509123  Hipermercado Carrefour -0.904205 -0.904205
# 10  7790387014136  Hipermercado Carrefour -0.882749 -0.882749
# 11  7792280005693  Hipermercado Carrefour -0.852686 -0.852686
# 12  7790070507273  Hipermercado Carrefour -0.772474 -0.772474
# 13  7792710006436  Hipermercado Carrefour -0.768839 -0.768839
# 14  7792710000182  Hipermercado Carrefour -0.729420 -0.729420
# 15  7790387014624  Hipermercado Carrefour -0.718317 -0.718317
# 16  7790480089734  Hipermercado Carrefour -0.711986 -0.711986
# 17  7790387014143  Hipermercado Carrefour -0.693436 -0.693436
# 18  7790387013610  Hipermercado Carrefour -0.682254 -0.682254
# 19  7792280005686  Hipermercado Carrefour -0.679365 -0.679365
#
#     id_producto_code
# 0                 39
# 1                  2
# 2                  5
# 3                 37
# 4                 25
# 5                 26
# 6                  4
# 7                  1
# 8                 44
# 9                  7
# 10                13
# 11                36
# 12                 0
# 13                43
# 14                42
# 15                16
# 16                24
# 17                14
# 18                10
# 19                35

# %%
plt.figure(figsize=(16, 6))
sns.barplot(data=df_sorted, y='min', x='id_producto', hue='comercio_bandera_nombre')

plt.xticks(rotation=90)
plt.title("Precio mínimo de los productos de Yerba")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16, 6))
sns.barplot(data=df_sorted, y='max', x='id_producto', hue='comercio_bandera_nombre')

plt.xticks(rotation=90)
plt.title("Precio máximo de los productos de Yerba")
plt.tight_layout()
plt.show()

# %%
sns.kdeplot(data=df_sorted, x='min', hue='comercio_bandera_nombre', fill=True)
plt.show()

# %%
sns.kdeplot(data=df_sorted, x='max', hue='comercio_bandera_nombre', fill=True)
plt.show()

# %%
promedios = productos_df_en_varias_sucursales.groupby('comercio_bandera_nombre')['precio_zscore'].mean().sort_values()
print(promedios)
# Out:
# comercio_bandera_nombre
# Hipermercado Carrefour   -0.556057
# Market                   -0.369840
# Express                  -0.060360
# Name: precio_zscore, dtype: float64

# %%
promedios.plot(kind='barh', color='skyblue')
plt.xlabel('Promedio del z-score de precio')
plt.title('Promedio de precio normalizado por categoría')
plt.tight_layout()
plt.show()
