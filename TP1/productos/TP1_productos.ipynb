# %%
pip install -r ../requirement.txt
# Out:
# Requirement already satisfied: pandas==2.2.3 in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from -r ../requirement.txt (line 1)) (2.2.3)
# Requirement already satisfied: openpyxl in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from -r ../requirement.txt (line 2)) (3.1.5)
# Requirement already satisfied: matplotlib in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from -r ../requirement.txt (line 3)) (3.10.3)
# Requirement already satisfied: seaborn in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from -r ../requirement.txt (line 4)) (0.13.2)
# Requirement already satisfied: scipy in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from -r ../requirement.txt (line 5)) (1.15.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from pandas==2.2.3->-r ../requirement.txt (line 1)) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from pandas==2.2.3->-r ../requirement.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from pandas==2.2.3->-r ../requirement.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from pandas==2.2.3->-r ../requirement.txt (line 1)) (2025.2)
# Requirement already satisfied: et-xmlfile in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from openpyxl->-r ../requirement.txt (line 2)) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from matplotlib->-r ../requirement.txt (line 3)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from matplotlib->-r ../requirement.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from matplotlib->-r ../requirement.txt (line 3)) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from matplotlib->-r ../requirement.txt (line 3)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from matplotlib->-r ../requirement.txt (line 3)) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from matplotlib->-r ../requirement.txt (line 3)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from matplotlib->-r ../requirement.txt (line 3)) (3.2.3)
# Requirement already satisfied: six>=1.5 in c:\users\mbernardo\desktop\postgrado\aprendizaje de maquina\env\lib\site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->-r ../requirement.txt (line 1)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# pd.set_option('display.float_format', '{:.6f}'.format)
# Mostrar todas las columnas sin límite
pd.set_option('display.max_columns', None)

# %%
# Leer el archivo CSV
productos_df = pd.read_csv('productos.zip', sep='|')

productos_df.head()
# Out:
# C:\Users\mbernardo\AppData\Local\Temp\ipykernel_34468\2831869706.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   productos_df = pd.read_csv('productos.zip', sep='|')
#   id_comercio  id_bandera  id_sucursal   id_producto  productos_ean  \
# 0          10         1.0         63.0  7.790771e+12            1.0
# 1          10         3.0        711.0  7.790070e+12            1.0
# 2          10         1.0         44.0  7.622202e+12            1.0
# 3          10         2.0         62.0  7.791293e+12            1.0
# 4          10         1.0          2.0  7.791720e+12            1.0
#
#                                productos_descripcion  \
# 0         TOALLA NOSOTRAS CLASICAS C CALENDULA X 16U
# 1         FIDEOS DEDALITOS LUCCHETTI BOLSA X 500 GRS
# 2        GALLETITAS BOCA DE DAMA TERRABUSI X 170 GRS
# 3  ACONDICIONADOR LISO EFECTO BOTOX TRESEMME X 25...
# 4             ANANA EN RODAJAS BULNEZ LATA X 825 GRS
#
#    productos_cantidad_presentacion productos_unidad_medida_presentacion  \
# 0                              1.0                                  UNI
# 1                              1.0                                  UNI
# 2                              1.0                                  UNI
# 3                              1.0                                  UNI
# 4                              1.0                                  UNI
#
#   productos_marca  productos_precio_lista  productos_precio_referencia  \
# 0        NOSOTRAS                  2809.0                       175.56
# 1       LUCCHETTI                  1339.0                      2678.00
# 2       TERRABUSI                   959.0                      5641.18
# 3        TRESEMME                  3969.0                     15876.00
# 4          BULNEZ                  2990.0                      3624.24
#
#    productos_cantidad_referencia productos_unidad_medida_referencia  \
# 0                           16.0                                UNI
# 1                          500.0                                GRM
# 2                          170.0                                GRM
# 3                          250.0                                CM3
# 4                          825.0                                GRM
#
#    productos_precio_unitario_promo1 productos_leyenda_promo1  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
#
#    productos_precio_unitario_promo2  productos_leyenda_promo2
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN

# %%
productos_df.dtypes
# Out:
# id_comercio                              object
# id_bandera                              float64
# id_sucursal                             float64
# id_producto                             float64
# productos_ean                           float64
# productos_descripcion                    object
# productos_cantidad_presentacion         float64
# productos_unidad_medida_presentacion     object
# productos_marca                          object
# productos_precio_lista                  float64
# productos_precio_referencia             float64
# productos_cantidad_referencia           float64
# productos_unidad_medida_referencia       object
# productos_precio_unitario_promo1        float64
# productos_leyenda_promo1                 object
# productos_precio_unitario_promo2        float64
# productos_leyenda_promo2                float64
# dtype: object

# %%
productos_df.describe()
# Out:
#          id_bandera   id_sucursal   id_producto  productos_ean  \
# count  2.232853e+06  2.232853e+06  2.232853e+06   2.232853e+06
# mean   2.065017e+00  3.166739e+02  7.322620e+12   9.777025e-01
# std    8.728486e-01  2.318601e+02  1.653917e+12   1.476493e-01
# min    1.000000e+00  1.000000e+00  4.008140e+07   0.000000e+00
# 25%    1.000000e+00  1.370000e+02  7.790315e+12   1.000000e+00
# 50%    2.000000e+00  2.560000e+02  7.791720e+12   1.000000e+00
# 75%    3.000000e+00  4.960000e+02  7.794521e+12   1.000000e+00
# max    3.000000e+00  8.100000e+02  9.002490e+12   1.000000e+00
#
#        productos_cantidad_presentacion  productos_precio_lista  \
# count                        2232853.0            2.232853e+06
# mean                               1.0            1.050002e+04
# std                                0.0            8.212710e+04
# min                                1.0            3.600000e+01
# 25%                                1.0            1.619000e+03
# 50%                                1.0            2.790000e+03
# 75%                                1.0            5.099000e+03
# max                                1.0            7.349000e+06
#
#        productos_precio_referencia  productos_cantidad_referencia  \
# count                 2.232853e+06                   2.232853e+06
# mean                  2.112866e+04                   3.965329e+02
# std                   9.270248e+04                   5.130412e+02
# min                   2.700000e-01                   0.000000e+00
# 25%                   3.610000e+03                   8.500000e+01
# 50%                   8.350000e+03                   2.370000e+02
# 75%                   1.695000e+04                   5.000000e+02
# max                   7.349000e+06                   8.000000e+03
#
#        productos_precio_unitario_promo1  productos_precio_unitario_promo2  \
# count                      6.870200e+04                               0.0
# mean                       6.686930e+04                               NaN
# std                        2.463596e+05                               NaN
# min                        4.500000e+01                               NaN
# 25%                        1.290000e+03                               NaN
# 50%                        1.990000e+03                               NaN
# 75%                        4.500000e+03                               NaN
# max                        6.849000e+06                               NaN
#
#        productos_leyenda_promo2
# count                       0.0
# mean                        NaN
# std                         NaN
# min                         NaN
# 25%                         NaN
# 50%                         NaN
# 75%                         NaN
# max                         NaN

# %%
productos_df.tail()
# Out:
#                                              id_comercio  id_bandera  \
# 2232849                                               10         2.0
# 2232850                                               10         3.0
# 2232851                                               10         3.0
# 2232852                                               10         3.0
# 2232853  Ultima actualización: 2025-05-02T05:00:43-03:00         NaN
#
#          id_sucursal   id_producto  productos_ean  \
# 2232849        512.0  2.509067e+12            0.0
# 2232850        736.0  7.790010e+12            1.0
# 2232851        748.0  7.730908e+12            1.0
# 2232852        450.0  7.790070e+12            1.0
# 2232853          NaN           NaN            NaN
#
#                                     productos_descripcion  \
# 2232849                        QUESO CREMOSO FRACC SILVIA
# 2232850  ACOND HIDRATACION INTENSA JOHNSONS KIDS X 200 CC
# 2232851        JUGO EN POLVO MIX FRUTAL RINDE DOS X 13GRS
# 2232852   FIDEOS INTEGRALES SPAGHETTI MATARAZZO X 500 GRS
# 2232853                                               NaN
#
#          productos_cantidad_presentacion productos_unidad_medida_presentacion  \
# 2232849                              1.0                                  KGM
# 2232850                              1.0                                  UNI
# 2232851                              1.0                                  UNI
# 2232852                              1.0                                  UNI
# 2232853                              NaN                                  NaN
#
#         productos_marca  productos_precio_lista  productos_precio_referencia  \
# 2232849             S/D                 14359.0                      14359.0
# 2232850   JOHNSONS BABY                  4965.0                      24825.0
# 2232851       RINDE DOS                   559.0                       4300.0
# 2232852       MATARAZZO                  2009.0                       4018.0
# 2232853             NaN                     NaN                          NaN
#
#          productos_cantidad_referencia productos_unidad_medida_referencia  \
# 2232849                         1000.0                                GRM
# 2232850                          200.0                                CM3
# 2232851                           13.0                                GRS
# 2232852                          500.0                                GRM
# 2232853                            NaN                                NaN
#
#          productos_precio_unitario_promo1  \
# 2232849                             790.0
# 2232850                            2310.0
# 2232851                               NaN
# 2232852                               NaN
# 2232853                               NaN
#
#                                   productos_leyenda_promo1  \
# 2232849  Promo A valida desde el 02/05/2025 hasta 04/05...
# 2232850  Promo A valida desde el 17/04/2025 hasta 20/05...
# 2232851                                                NaN
# 2232852                                                NaN
# 2232853                                                NaN
#
#          productos_precio_unitario_promo2  productos_leyenda_promo2
# 2232849                               NaN                       NaN
# 2232850                               NaN                       NaN
# 2232851                               NaN                       NaN
# 2232852                               NaN                       NaN
# 2232853                               NaN                       NaN

# %%
#notamos que el ultimo registro de cada csv es irrelevante
productos_df = productos_df.drop(productos_df.index[-1])

# %%
productos_df.isnull().sum()
# Out:
# id_comercio                                   0
# id_bandera                                    0
# id_sucursal                                   0
# id_producto                                   0
# productos_ean                                 0
# productos_descripcion                         0
# productos_cantidad_presentacion               0
# productos_unidad_medida_presentacion          0
# productos_marca                               0
# productos_precio_lista                        0
# productos_precio_referencia                   0
# productos_cantidad_referencia                 0
# productos_unidad_medida_referencia            0
# productos_precio_unitario_promo1        2164151
# productos_leyenda_promo1                2164151
# productos_precio_unitario_promo2        2232853
# productos_leyenda_promo2                2232853
# dtype: int64

# %%
len(productos_df)
# Out:
# 2232853

# %%
productos_df.columns
# Out:
# Index(['id_comercio', 'id_bandera', 'id_sucursal', 'id_producto',
#        'productos_ean', 'productos_descripcion',
#        'productos_cantidad_presentacion',
#        'productos_unidad_medida_presentacion', 'productos_marca',
#        'productos_precio_lista', 'productos_precio_referencia',
#        'productos_cantidad_referencia', 'productos_unidad_medida_referencia',
#        'productos_precio_unitario_promo1', 'productos_leyenda_promo1',
#        'productos_precio_unitario_promo2', 'productos_leyenda_promo2'],
#       dtype='object')

# %%
# verificamos cuantos registros tienen el codigo de producto EAN y cuantos no
productos_df['productos_ean'].value_counts()
# Out:
# productos_ean
# 1.0    2183066
# 0.0      49787
# Name: count, dtype: int64

# %%
productos_df['productos_ean'].duplicated().sum()
# Out:
# np.int64(2232851)

# %%
#Verificamos que no haya un id_producto repetido como ean y como NO ean
mask = productos_df.groupby('id_producto')['productos_ean'].nunique() > 1

# Filtrar el DataFrame original con los valores que cumplen la condición
df_filtrado = productos_df[productos_df['id_producto'].isin(mask[mask].index)]
df_filtrado.head()
# Out:
# Empty DataFrame
# Columns: [id_comercio, id_bandera, id_sucursal, id_producto, productos_ean, productos_descripcion, productos_cantidad_presentacion, productos_unidad_medida_presentacion, productos_marca, productos_precio_lista, productos_precio_referencia, productos_cantidad_referencia, productos_unidad_medida_referencia, productos_precio_unitario_promo1, productos_leyenda_promo1, productos_precio_unitario_promo2, productos_leyenda_promo2]
# Index: []

# %%
columnas_de_interes = [ 'id_sucursal', 'id_producto',
       'productos_ean',
       'productos_cantidad_presentacion',
       'productos_unidad_medida_presentacion', 'productos_marca',
       'productos_precio_lista', 'productos_precio_referencia',
       'productos_cantidad_referencia', 'productos_unidad_medida_referencia',
       'productos_precio_unitario_promo1', 'productos_leyenda_promo1',
       'productos_precio_unitario_promo2', 'productos_leyenda_promo2']

# %%
productos_df = productos_df[columnas_de_interes]
productos_df.head()
# Out:
#    id_sucursal   id_producto  productos_ean  productos_cantidad_presentacion  \
# 0         63.0  7.790771e+12            1.0                              1.0
# 1        711.0  7.790070e+12            1.0                              1.0
# 2         44.0  7.622202e+12            1.0                              1.0
# 3         62.0  7.791293e+12            1.0                              1.0
# 4          2.0  7.791720e+12            1.0                              1.0
#
#   productos_unidad_medida_presentacion productos_marca  \
# 0                                  UNI        NOSOTRAS
# 1                                  UNI       LUCCHETTI
# 2                                  UNI       TERRABUSI
# 3                                  UNI        TRESEMME
# 4                                  UNI          BULNEZ
#
#    productos_precio_lista  productos_precio_referencia  \
# 0                  2809.0                       175.56
# 1                  1339.0                      2678.00
# 2                   959.0                      5641.18
# 3                  3969.0                     15876.00
# 4                  2990.0                      3624.24
#
#    productos_cantidad_referencia productos_unidad_medida_referencia  \
# 0                           16.0                                UNI
# 1                          500.0                                GRM
# 2                          170.0                                GRM
# 3                          250.0                                CM3
# 4                          825.0                                GRM
#
#    productos_precio_unitario_promo1 productos_leyenda_promo1  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
#
#    productos_precio_unitario_promo2  productos_leyenda_promo2
# 0                               NaN                       NaN
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN

# %%
productos_df['id_sucursal'] = productos_df['id_sucursal'].astype(int)
productos_df['productos_ean'] = productos_df['productos_ean'].astype(int).astype(bool)
productos_df['id_producto'] = productos_df['id_producto'].astype(int).astype(str)
productos_df['productos_unidad_medida_presentacion'] = productos_df['productos_unidad_medida_presentacion'].astype('category')
productos_df['productos_marca'] = productos_df['productos_marca'].astype('category')
productos_df['productos_unidad_medida_referencia'] = productos_df['productos_unidad_medida_referencia'].astype('category')
productos_df['precio_zscore'] = productos_df.groupby('id_producto')['productos_precio_referencia'].transform(
    lambda x: (x - x.mean()) / x.std()
)
productos_df.head()
# Out:
#    id_sucursal    id_producto  productos_ean  productos_cantidad_presentacion  \
# 0           63  7790770601899           True                              1.0
# 1          711  7790070318398           True                              1.0
# 2           44  7622201808860           True                              1.0
# 3           62  7791293050089           True                              1.0
# 4            2  7791720018088           True                              1.0
#
#   productos_unidad_medida_presentacion productos_marca  \
# 0                                  UNI        NOSOTRAS
# 1                                  UNI       LUCCHETTI
# 2                                  UNI       TERRABUSI
# 3                                  UNI        TRESEMME
# 4                                  UNI          BULNEZ
#
#    productos_precio_lista  productos_precio_referencia  \
# 0                  2809.0                       175.56
# 1                  1339.0                      2678.00
# 2                   959.0                      5641.18
# 3                  3969.0                     15876.00
# 4                  2990.0                      3624.24
#
#    productos_cantidad_referencia productos_unidad_medida_referencia  \
# 0                           16.0                                UNI
# 1                          500.0                                GRM
# 2                          170.0                                GRM
# 3                          250.0                                CM3
# 4                          825.0                                GRM
#
#    productos_precio_unitario_promo1 productos_leyenda_promo1  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
#
#    productos_precio_unitario_promo2  productos_leyenda_promo2  precio_zscore
# 0                               NaN                       NaN       1.427526
# 1                               NaN                       NaN      -0.260738
# 2                               NaN                       NaN      -2.846394
# 3                               NaN                       NaN      -0.689593
# 4                               NaN                       NaN       0.996748

# %%
productos_df["id_producto"].nunique()
# Out:
# 15863

# %%
productos_df["id_producto"].value_counts()
# Out:
# id_producto
# 7790070336118    567
# 7798159716004    567
# 7790742363008    567
# 7790520009494    567
# 7791293047164    567
#                 ...
# 7793147001704      1
# 7796885402642      1
# 7794211005031      1
# 7796962985617      1
# 2509103000002      1
# Name: count, Length: 15863, dtype: int64

# %% [markdown]
# De la ultima celda podemos analizar que hay productos que estan en TODAS las sucursales y que hay productos que no

# %%
productos_df["productos_marca"].value_counts()
# Out:
# productos_marca
# CARREFOUR            174141
# S/D                  127084
# CARREFOUR CLASSIC    100935
# BULNEZ                54743
# CARREFOUR CRISTAL     47242
#                       ...
# MUJERCITAS                1
# DROGHERIA                 1
# VERONICA                  1
# ESPUNA                    1
# AGUA NUESTRA              1
# Name: count, Length: 1480, dtype: int64

# %%
# Leer el archivo Excel
sucursales_df = pd.read_excel('../sucursales/sucursales_procesado.xlsx')
sucursales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id_bandera               567 non-null    int64
#  1   id_sucursal              567 non-null    int64
#  2   sucursales_nombre        567 non-null    object
#  3   sucursales_tipo          567 non-null    object
#  4   sucursales_latitud       567 non-null    float64
#  5   sucursales_longitud      567 non-null    float64
#  6   sucursales_barrio        303 non-null    object
#  7   sucursales_localidad     567 non-null    object
#  8   sucursales_provincia     567 non-null    object
#  9   comercio_bandera_nombre  567 non-null    object
#  10  localidad_provincia      567 non-null    object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 48.9+ KB

# %%
#Uno los dataframe por la columna de id_sucursal
df_completo = pd.merge(productos_df, sucursales_df, on='id_sucursal', how='left')
df_completo.head()
# Out:
#    id_sucursal    id_producto  productos_ean  productos_cantidad_presentacion  \
# 0           63  7790770601899           True                              1.0
# 1          711  7790070318398           True                              1.0
# 2           44  7622201808860           True                              1.0
# 3           62  7791293050089           True                              1.0
# 4            2  7791720018088           True                              1.0
#
#   productos_unidad_medida_presentacion productos_marca  \
# 0                                  UNI        NOSOTRAS
# 1                                  UNI       LUCCHETTI
# 2                                  UNI       TERRABUSI
# 3                                  UNI        TRESEMME
# 4                                  UNI          BULNEZ
#
#    productos_precio_lista  productos_precio_referencia  \
# 0                  2809.0                       175.56
# 1                  1339.0                      2678.00
# 2                   959.0                      5641.18
# 3                  3969.0                     15876.00
# 4                  2990.0                      3624.24
#
#    productos_cantidad_referencia productos_unidad_medida_referencia  \
# 0                           16.0                                UNI
# 1                          500.0                                GRM
# 2                          170.0                                GRM
# 3                          250.0                                CM3
# 4                          825.0                                GRM
#
#    productos_precio_unitario_promo1 productos_leyenda_promo1  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
#
#    productos_precio_unitario_promo2  productos_leyenda_promo2  precio_zscore  \
# 0                               NaN                       NaN       1.427526
# 1                               NaN                       NaN      -0.260738
# 2                               NaN                       NaN      -2.846394
# 3                               NaN                       NaN      -0.689593
# 4                               NaN                       NaN       0.996748
#
#    id_bandera   sucursales_nombre sucursales_tipo  sucursales_latitud  \
# 0           1       Caleta Olivia    Hipermercado          -46.444906
# 1           3  Álvarez Thomas 372    Autoservicio          -34.581280
# 2           1      Resistencia II    Hipermercado          -27.438800
# 3           2          Champagnat    Hipermercado          -34.449813
# 4           1       Vicente López    Hipermercado          -34.532302
#
#    sucursales_longitud sucursales_barrio             sucursales_localidad  \
# 0           -67.533789               NaN                       Santa Cruz
# 1           -58.449050        Colegiales  Ciudad Autónoma de Buenos Aires
# 2           -58.987383               NaN                      Resistencia
# 3           -58.916319               NaN                            Pilar
# 4           -58.468176               NaN                    Vicente López
#
#   sucursales_provincia comercio_bandera_nombre  \
# 0           Santa Cruz  Hipermercado Carrefour
# 1                 CABA                 Express
# 2                Chaco  Hipermercado Carrefour
# 3         Buenos Aires                  Market
# 4         Buenos Aires  Hipermercado Carrefour
#
#                       localidad_provincia
# 0                 Santa Cruz - Santa Cruz
# 1  Ciudad Autónoma de Buenos Aires - CABA
# 2                     Resistencia - Chaco
# 3                    Pilar - Buenos Aires
# 4            Vicente López - Buenos Aires

# %%
#Vamos a analizar las sucursales que son del tipo supermercado
completo_supermercado_df = df_completo[df_completo['sucursales_tipo'] == 'Supermercado']
completo_supermercado_df.head()
# Out:
#    id_sucursal    id_producto  productos_ean  productos_cantidad_presentacion  \
# 5          130  7798151952981           True                              1.0
# 6          438  7791293045733           True                              1.0
# 7          290  7790070933638           True                              1.0
# 8          295  7790132098459           True                              1.0
# 9          272  7790990999868           True                              1.0
#
#   productos_unidad_medida_presentacion productos_marca  \
# 5                                  UNI            KING
# 6                                  UNI           SEDAL
# 7                                  UNI        ARLISTAN
# 8                                  UNI          AYUDIN
# 9                                  UNI           ZORRO
#
#    productos_precio_lista  productos_precio_referencia  \
# 5                  1400.0                      8000.00
# 6                  4255.0                     12514.71
# 7                  7475.0                     43970.59
# 8                  1169.0                      1169.00
# 9                  2209.0                      4418.00
#
#    productos_cantidad_referencia productos_unidad_medida_referencia  \
# 5                          175.0                                GRM
# 6                          340.0                                CM3
# 7                          170.0                                GRM
# 8                         1000.0                                CM3
# 9                          500.0                                CM3
#
#    productos_precio_unitario_promo1 productos_leyenda_promo1  \
# 5                               NaN                      NaN
# 6                               NaN                      NaN
# 7                               NaN                      NaN
# 8                               NaN                      NaN
# 9                               NaN                      NaN
#
#    productos_precio_unitario_promo2  productos_leyenda_promo2  precio_zscore  \
# 5                               NaN                       NaN      -0.357614
# 6                               NaN                       NaN       0.425358
# 7                               NaN                       NaN      -1.234778
# 8                               NaN                       NaN      -0.432809
# 9                               NaN                       NaN      -0.294340
#
#    id_bandera     sucursales_nombre sucursales_tipo  sucursales_latitud  \
# 5           2  Mar del Plata Centro    Supermercado          -37.998923
# 6           3       25 de Mayo 2650    Supermercado          -34.500302
# 7           2        Mendoza Bombal    Supermercado          -32.903094
# 8           2    Córdoba Granaderos    Supermercado          -31.374529
# 9           2       San Fernando II    Supermercado          -34.441795
#
#    sucursales_longitud sucursales_barrio sucursales_localidad  \
# 5           -57.553648               NaN        Mar del Plata
# 6           -58.694886               NaN       Los Polvorines
# 7           -68.852428               NaN           Godoy Cruz
# 8           -64.213855               NaN           Alto Verde
# 9           -58.553738               NaN         San Fernando
#
#   sucursales_provincia comercio_bandera_nombre            localidad_provincia
# 5         Buenos Aires                  Market   Mar del Plata - Buenos Aires
# 6         Buenos Aires                 Express  Los Polvorines - Buenos Aires
# 7              Mendoza                  Market           Godoy Cruz - Mendoza
# 8              Córdoba                  Market           Alto Verde - Córdoba
# 9         Buenos Aires                  Market    San Fernando - Buenos Aires

# %%
# Contar el número de sucursales únicas por producto
productos_en_todas_sucursales = completo_supermercado_df.groupby('id_producto')['comercio_bandera_nombre'].nunique()

# Filtrar los productos que están en todas los comercios, que en nuestro caso son 3, expres, hiper, market
productos_en_todas_sucursales = productos_en_todas_sucursales[productos_en_todas_sucursales == 3].index

# Filtrar el DataFrame original
productos_df_en_varias_sucursales = completo_supermercado_df[completo_supermercado_df['id_producto'].isin(productos_en_todas_sucursales)]
print(f" cantidad de productos que estan en los 3 comercios {len(productos_df_en_varias_sucursales["id_producto"].value_counts())}")
productos_df_en_varias_sucursales["id_producto"].value_counts()
# Out:
#  cantidad de productos que estan en los 3 comercios 3436
# id_producto
# 7791720032725    111
# 7798119220183    111
# 7509546686042    111
# 7791720019221    111
# 7791200200583    111
#                 ...
# 2507258000007      5
# 7791720033371      4
# 7791720037775      4
# 7798159717636      4
# 7790894900557      3
# Name: count, Length: 3436, dtype: int64

# %%
# Agrupar por id_producto y comercio_bandera_nombre y calcular el máximo y mínimo de precio_zscore
resultado = productos_df_en_varias_sucursales.groupby(['id_producto', 'comercio_bandera_nombre'])['precio_zscore'].agg(['max', 'min']).reset_index()

resultado["id_producto"].value_counts()
# Out:
# id_producto
# 99176316565      3
# 2506052000008    3
# 2506055000005    3
# 2506610000006    3
# 2507258000007    3
#                 ..
# 2507520000001    3
# 2507519000005    3
# 2507518000006    3
# 2507513000001    3
# 2507483000001    3
# Name: count, Length: 3436, dtype: int64

# %%
resultado.head()
# Out:
#      id_producto comercio_bandera_nombre       max       min
# 0  2506052000008                 Express -0.037421 -0.037421
# 1  2506052000008  Hipermercado Carrefour  3.323188 -1.653393
# 2  2506052000008                  Market  2.443977 -3.136104
# 3  2506055000005                 Express  0.147527  0.147527
# 4  2506055000005  Hipermercado Carrefour  2.472754 -0.916014

# %%
# Ordenar el DataFrame por la columna 'id_producto'
resultado = resultado.sort_values(by='max').reset_index(drop=True)

# Convertir la columna 'id_producto' a categórica
resultado['id_producto'] = resultado['id_producto'].astype('category')

# Agregar una nueva columna con el código numérico de la categoría
resultado['id_producto_code'] = resultado['id_producto'].cat.codes

resultado.head(20)
# Out:
#       id_producto comercio_bandera_nombre        max        min  \
# 0   7791519702105  Hipermercado Carrefour -11.401693 -11.401693
# 1        77982704  Hipermercado Carrefour  -8.834731  -8.834731
# 2   7796885486727                 Express  -8.767665  -8.767665
# 3        77982698  Hipermercado Carrefour  -8.745327  -8.745327
# 4   7790070320032                  Market  -6.304077  -6.304077
# 5   7798126291060  Hipermercado Carrefour  -4.473470  -4.473470
# 6   7798054011105  Hipermercado Carrefour  -4.115424  -4.115424
# 7   7790250040798  Hipermercado Carrefour  -3.789840  -3.789840
# 8   7790070320032  Hipermercado Carrefour  -3.551615  -3.551615
# 9   7793253005238                  Market  -3.328362  -3.328362
# 10       77927361  Hipermercado Carrefour  -3.255315  -3.255315
# 11  7791274193415  Hipermercado Carrefour  -2.956396  -2.956396
# 12  7790895012273                  Market  -2.694347  -2.694347
# 13  7790895012273  Hipermercado Carrefour  -2.694347  -2.694347
# 14  7798342151155  Hipermercado Carrefour  -2.574037  -2.758865
# 15  7790895646935  Hipermercado Carrefour  -2.568685  -2.568685
# 16  7798171572763  Hipermercado Carrefour  -2.393293  -2.393293
# 17  7790895012310  Hipermercado Carrefour  -2.198498  -2.198498
# 18  7790895012440  Hipermercado Carrefour  -2.170023  -2.170023
# 19  7790742192202  Hipermercado Carrefour  -2.157802  -2.157802
#
#     id_producto_code
# 0               1595
# 1               3202
# 2               2684
# 3               3201
# 4                456
# 5               2953
# 6               2818
# 7                699
# 8                456
# 9               2404
# 10              2299
# 11              1359
# 12              1168
# 13              1168
# 14              3243
# 15              1196
# 16              3150
# 17              1169
# 18              1170
# 19              1069

# %%
plt.figure(figsize=(12, 6))
df_sorted = resultado.sort_values(by=['comercio_bandera_nombre', 'id_producto_code'])

sns.lineplot(
    data=df_sorted,
    x='id_producto_code',
    y='min',
    hue='comercio_bandera_nombre',       # Diferenciar por tipo
    palette='Set1',   # Paleta de colores (opcional)
    estimator=None,      # Mostrar todos los puntos (sin estimación)
    legend='full'           # Tamaño de los puntos
)

# Agregar título y etiquetas
plt.title('Precio vs Código por Tipo')
plt.xlabel('Código')
plt.ylabel('Precio')
plt.xlim(0, 10)
plt.legend(title='Tipo')  # Opcional: título de la leyenda
plt.show()

# %%
sns.kdeplot(data=df_sorted, x='max', hue='comercio_bandera_nombre', fill=True)
plt.show()
