# %%
pip install -r ../requirement.txt
# Out:
# Requirement already satisfied: pandas==2.2.3 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirement.txt (line 1)) (2.2.3)
# Requirement already satisfied: openpyxl in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirement.txt (line 2)) (3.1.5)
# Requirement already satisfied: matplotlib in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirement.txt (line 3)) (3.10.3)
# Requirement already satisfied: seaborn in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirement.txt (line 4)) (0.13.2)
# Requirement already satisfied: scipy in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirement.txt (line 5)) (1.15.3)
# Requirement already satisfied: numpy>=1.23.2 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from pandas==2.2.3->-r ../requirement.txt (line 1)) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from pandas==2.2.3->-r ../requirement.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from pandas==2.2.3->-r ../requirement.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from pandas==2.2.3->-r ../requirement.txt (line 1)) (2025.2)
# Requirement already satisfied: et-xmlfile in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from openpyxl->-r ../requirement.txt (line 2)) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirement.txt (line 3)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirement.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirement.txt (line 3)) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirement.txt (line 3)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirement.txt (line 3)) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirement.txt (line 3)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirement.txt (line 3)) (3.2.3)
# Requirement already satisfied: six>=1.5 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->-r ../requirement.txt (line 1)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# pd.set_option('display.float_format', '{:.6f}'.format)
# Mostrar todas las columnas sin límite
pd.set_option('display.max_columns', None)

# %% [markdown]
# ##### **Precios de la Yerba Mate**
#
# Iniciamos analizando los precios de los productos de Yerba Mate dado que son un producto de consumo masivo presente en todo el territorio nacional.

# %%
colores = {
    'Express': 'orange',
    'Market': 'red',
    'Hipermercado Carrefour': 'blue',
}
productos_df = pd.read_csv('productos_procesado.zip', sep='|')

# Al leer el csv las columnas vuelven a ser sus tipos nativos entonces las reconvertimon a categóricas
productos_df['id_sucursal'] = productos_df['id_sucursal'].astype('category')
productos_df['id_producto'] = productos_df['id_producto'].astype('category')
productos_df['productos_unidad_medida_presentacion'] = productos_df['productos_unidad_medida_presentacion'].astype('category')
productos_df['productos_marca'] = productos_df['productos_marca'].astype('category')
productos_df['productos_unidad_medida_referencia'] = productos_df['productos_unidad_medida_referencia'].astype('category')
productos_df['comercio_bandera_nombre'] = productos_df['comercio_bandera_nombre'].astype('category')
productos_df['id_producto_code'] = productos_df['id_producto'].cat.codes

productos_df = productos_df[productos_df['productos_descripcion'].str.contains('yerba', case=False, na=False)]
display(productos_df.head())
display(productos_df.info())
# Out:
#     id_sucursal    id_producto  productos_ean  \
# 68          109  7790710334641           True
# 223         134  7790387014624           True
# 273         226  7790070509109           True
# 294         115  7790710334641           True
# 319         195  7798067630010           True
#
#                                  productos_descripcion  \
# 68   YERBA MATE SILUETA NARNJA CBSE CORMILLOT X 500...
# 223       YERBA MATE SUAVE ORIG CONTROL UNION X 500GRS
# 273          YERBA MATE SUAVE NOBLEZA GAUCHA X 500 GRS
# 294  YERBA MATE SILUETA NARNJA CBSE CORMILLOT X 500...
# 319                  YERBA COMPUESTA ARREGUI X 500 GRS
#
#      productos_cantidad_presentacion productos_unidad_medida_presentacion  \
# 68                               1.0                                  UNI
# 223                              1.0                                  UNI
# 273                              1.0                                  UNI
# 294                              1.0                                  UNI
# 319                              1.0                                  UNI
#
#     productos_marca  productos_precio_lista  productos_precio_referencia  \
# 68             CBSE                  1699.0                       3398.0
# 223           UNION                  2500.0                       5000.0
# 273  NOBLEZA GAUCHA                  1645.0                       3290.0
# 294            CBSE                  1699.0                       3398.0
# 319         ARREGUI                  1600.0                       3200.0
#
#      productos_cantidad_referencia productos_unidad_medida_referencia  \
# 68                           500.0                                GRM
# 223                          500.0                                GRM
# 273                          500.0                                GRM
# 294                          500.0                                GRM
# 319                          500.0                                GRM
#
#      productos_precio_unitario_promo1  \
# 68                                NaN
# 223                               NaN
# 273                               NaN
# 294                               NaN
# 319                            1450.0
#
#                               productos_leyenda_promo1  \
# 68                                                 NaN
# 223                                                NaN
# 273                                                NaN
# 294                                                NaN
# 319  Promo A valida desde el 01/05/2025 hasta 30/05...
#
#      productos_precio_unitario_promo2  productos_leyenda_promo2  \
# 68                                NaN                       NaN
# 223                               NaN                       NaN
# 273                               NaN                       NaN
# 294                               NaN                       NaN
# 319                               NaN                       NaN
#
#      precio_zscore  id_bandera  sucursales_nombre sucursales_tipo  \
# 68       -1.484866           2         La Plata I    Supermercado
# 223      -0.263978           2          Tandil II    Supermercado
# 273      -0.663624           2  Martínez (Edison)    Supermercado
# 294      -1.484866           2             Flores    Supermercado
# 319      -0.263702           2           Olazabal    Supermercado
#
#      sucursales_latitud  sucursales_longitud sucursales_barrio  \
# 68           -34.913497           -57.951821               NaN
# 223          -37.326474           -59.135087               NaN
# 273          -34.492689           -58.499192               NaN
# 294          -34.627423           -58.458170               NaN
# 319          -34.574379           -58.482128               NaN
#
#                 sucursales_localidad sucursales_provincia  \
# 68                          La Plata         Buenos Aires
# 223                           Tandil         Buenos Aires
# 273                         Martínez         Buenos Aires
# 294  Ciudad Autónoma de Buenos Aires                 CABA
# 319  Ciudad Autónoma de Buenos Aires                 CABA
#
#     comercio_bandera_nombre                     localidad_provincia  \
# 68                   Market                 La Plata - Buenos Aires
# 223                  Market                   Tandil - Buenos Aires
# 273                  Market                 Martínez - Buenos Aires
# 294                  Market  Ciudad Autónoma de Buenos Aires - CABA
# 319                  Market  Ciudad Autónoma de Buenos Aires - CABA
#
#      id_producto_code
# 68               4179
# 223              3453
# 273              2608
# 294              4179
# 319              9277
# <class 'pandas.core.frame.DataFrame'>
# Index: 5248 entries, 68 to 370457
# Data columns (total 27 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   id_sucursal                           5248 non-null   category
#  1   id_producto                           5248 non-null   category
#  2   productos_ean                         5248 non-null   bool
#  3   productos_descripcion                 5248 non-null   object
#  4   productos_cantidad_presentacion       5248 non-null   float64
#  5   productos_unidad_medida_presentacion  5248 non-null   category
#  6   productos_marca                       5248 non-null   category
#  7   productos_precio_lista                5248 non-null   float64
#  8   productos_precio_referencia           5248 non-null   float64
#  9   productos_cantidad_referencia         5248 non-null   float64
#  10  productos_unidad_medida_referencia    5248 non-null   category
#  11  productos_precio_unitario_promo1      55 non-null     float64
#  12  productos_leyenda_promo1              55 non-null     object
#  13  productos_precio_unitario_promo2      0 non-null      float64
#  14  productos_leyenda_promo2              0 non-null      float64
#  15  precio_zscore                         5182 non-null   float64
#  16  id_bandera                            5248 non-null   int64
#  17  sucursales_nombre                     5248 non-null   object
#  18  sucursales_tipo                       5248 non-null   object
#  19  sucursales_latitud                    5248 non-null   float64
#  20  sucursales_longitud                   5248 non-null   float64
#  21  sucursales_barrio                     718 non-null    object
#  22  sucursales_localidad                  5248 non-null   object
#  23  sucursales_provincia                  5248 non-null   object
#  24  comercio_bandera_nombre               5248 non-null   category
#  25  localidad_provincia                   5248 non-null   object
#  26  id_producto_code                      5248 non-null   int16
# dtypes: bool(1), category(6), float64(10), int16(1), int64(1), object(8)
# memory usage: 1.2+ MB
# None

# %%
productos_df["id_producto"].nunique()
# Out:
# 121

# %%
productos_df["id_producto"].value_counts()
# Out:
# id_producto
# 7791720024782    77
# 7790387013634    77
# 7791720024751    77
# 7790387014624    77
# 7792280005709    77
#                  ..
# 7790580131760     0
# 7790580131876     0
# 7790580132163     0
# 7790580132170     0
# 9002490258313     0
# Name: count, Length: 11560, dtype: int64

# %% [markdown]
# De la ultima celda podemos analizar que hay productos que estan en TODAS las sucursales y que hay productos que no

# %% [markdown]
# Para tener un análisis acorde tomamos aquellos productos de bebidas no alcóholicas que están en los tres tipos de comercios.

# %%
# Contar el número de sucursales únicas por producto
productos_en_todas_sucursales = productos_df.groupby('id_producto')['comercio_bandera_nombre'].nunique()

# Filtrar los productos que están en todas los comercios, que en nuestro caso son 3, expres, hiper, market
productos_en_todas_sucursales = productos_en_todas_sucursales[productos_en_todas_sucursales == 3].index

# Filtrar el DataFrame original
productos_df_en_varias_sucursales = productos_df[productos_df['id_producto'].isin(productos_en_todas_sucursales)]
print(f"Cantidad de productos que estan en los 3 comercios: {len(productos_df_en_varias_sucursales['id_producto'].value_counts())}")
# Out:
# Cantidad de productos que estan en los 3 comercios: 11560
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_29491/3276425499.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   productos_en_todas_sucursales = productos_df.groupby('id_producto')['comercio_bandera_nombre'].nunique()

# %% [markdown]
# Analizamos el precio máximo y mínimo de cada producto agrupado por el tipo de comercio.

# %%
print("Cantidad de productos para cada tipo de comercio:")
print(productos_df_en_varias_sucursales['comercio_bandera_nombre'].value_counts())

# Agrupar por id_producto y comercio_bandera_nombre y calcular el máximo y mínimo de precio_zscore
resultado = productos_df_en_varias_sucursales.groupby(['id_producto_code', 'comercio_bandera_nombre'])['precio_zscore'].agg(['max', 'min']).reset_index()

resultado.head()
# Out:
# Cantidad de productos para cada tipo de comercio:
# comercio_bandera_nombre
# Market                    2384
# Express                   1054
# Hipermercado Carrefour      50
# Name: count, dtype: int64
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_29491/379206894.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   resultado = productos_df_en_varias_sucursales.groupby(['id_producto_code', 'comercio_bandera_nombre'])['precio_zscore'].agg(['max', 'min']).reset_index()
#    id_producto_code comercio_bandera_nombre       max       min
# 0              2595                 Express  1.331063  1.331063
# 1              2595  Hipermercado Carrefour -0.772474 -0.772474
# 2              2595                  Market  1.331063 -1.209157
# 3              2596                 Express -0.061380 -0.061380
# 4              2596  Hipermercado Carrefour -1.067405 -1.067405

# %%
plt.figure(figsize=(30, 10))
sns.barplot(data=resultado, y='min', x='id_producto_code', hue='comercio_bandera_nombre', palette=colores)

plt.xticks(rotation=90)
plt.title("Precio mínimo de los productos")
plt.ylabel('Precio mínimo normalizado')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(30, 10))
sns.barplot(data=resultado, y='max', x='id_producto_code', hue='comercio_bandera_nombre', palette=colores)

plt.xticks(rotation=90)
plt.title("Precio máximo de los productos")
plt.ylabel('Precio máximo normalizado')
plt.tight_layout()
plt.show()

# %%
sns.kdeplot(data=resultado, x='min', hue='comercio_bandera_nombre', fill=True, palette=colores)
plt.xlabel('Precio mínimo normalizado')
plt.show()

# %%
sns.kdeplot(data=resultado, x='max', hue='comercio_bandera_nombre', fill=True, palette=colores)
plt.xlabel('Precio máximo normalizado')
plt.show()

# %%
promedios = productos_df_en_varias_sucursales.groupby('comercio_bandera_nombre')['precio_zscore'].mean().sort_values()
# Hacer el gráfico de barras
colores_barras = [colores[nombre] for nombre in promedios.index]
promedios.plot(kind='barh', color=colores_barras, figsize=(10, 6), alpha=0.7)
plt.xlabel('Promedio del z-score de precio')
plt.ylabel('Tipo de comercio')
plt.title('Promedio de precio normalizado por categoría')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_29491/1290604422.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedios = productos_df_en_varias_sucursales.groupby('comercio_bandera_nombre')['precio_zscore'].mean().sort_values()
