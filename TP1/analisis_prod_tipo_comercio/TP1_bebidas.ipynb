# %%
pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas==2.2.3 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: openpyxl in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (3.1.5)
# Requirement already satisfied: matplotlib in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (3.10.3)
# Requirement already satisfied: seaborn in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: scipy in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 5)) (1.15.3)
# Requirement already satisfied: scikit-learn in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 6)) (1.6.1)
# Requirement already satisfied: numpy>=1.23.2 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from pandas==2.2.3->-r ../requirements.txt (line 1)) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from pandas==2.2.3->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from pandas==2.2.3->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from pandas==2.2.3->-r ../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: et-xmlfile in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from openpyxl->-r ../requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from matplotlib->-r ../requirements.txt (line 3)) (3.2.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from scikit-learn->-r ../requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from scikit-learn->-r ../requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: six>=1.5 in /Users/alejandronicolastacchella/Documents/Personal/Maestría IA/AdD/ceia_add_tps/.venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3->-r ../requirements.txt (line 1)) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Mostrar todas las columnas sin límite
pd.set_option('display.max_columns', None)

# %% [markdown]
# ##### **Precios de las bebidas no alcóholicas**
#
# Iniciamos analizando los precios de los productos de bebidas no alcóholicas dado que son un producto de consumo masivo presente en todo el territorio nacional.

# %%
colores = {
    'Express': 'orange',
    'Market': 'red',
    'Hipermercado Carrefour': 'blue',
}
productos_df = pd.read_csv('productos_procesado.zip', sep='|')

# Al leer el csv las columnas vuelven a ser sus tipos nativos entonces las reconvertimon a categóricas
productos_df['id_sucursal'] = productos_df['id_sucursal'].astype('category')
productos_df['id_producto'] = productos_df['id_producto'].astype('category')
productos_df['productos_unidad_medida_presentacion'] = productos_df['productos_unidad_medida_presentacion'].astype('category')
productos_df['productos_marca'] = productos_df['productos_marca'].astype('category')
productos_df['productos_unidad_medida_referencia'] = productos_df['productos_unidad_medida_referencia'].astype('category')
productos_df['comercio_bandera_nombre'] = productos_df['comercio_bandera_nombre'].astype('category')
productos_df['id_producto_code'] = productos_df['id_producto'].cat.codes

productos_df = productos_df[productos_df['productos_descripcion'].str.contains('^gaseosa|^agua', case=False, na=False)]
display(productos_df.head())
display(productos_df.info())
# Out:
#     id_sucursal    id_producto  productos_ean  \
# 6           120  7791813402022           True
# 7           209  7791720029978           True
# 52          258  7790895000997           True
# 93          477  7791813421603           True
# 130         256  7798159715755           True
#
#                                  productos_descripcion  \
# 6            AGUA SABORIZADA LIMON S GAS H2OH X 500 CC
# 7    GASEOSA LIGHT POMELO CARREFOUR CLASSIC PET X2....
# 52        GASEOSA COLA REGULAR COCA COLA PET X 2.25 LT
# 93      AGUA SABORIZADA CITRUS C GAS H2OH PET X 1.5 LT
# 130         GASEOSA TONICA REG CARREFOUR PET X 2.25 LT
#
#      productos_cantidad_presentacion productos_unidad_medida_presentacion  \
# 6                                1.0                                  UNI
# 7                                1.0                                  UNI
# 52                               1.0                                  UNI
# 93                               1.0                                  UNI
# 130                              1.0                                  UNI
#
#        productos_marca  productos_precio_lista  productos_precio_referencia  \
# 6                H2OH!                  1400.0                      2800.00
# 7    CARREFOUR CLASSIC                  1540.0                       684.44
# 52           COCA COLA                  4200.0                      1866.67
# 93               H2OH!                  2159.0                      1439.33
# 130          CARREFOUR                  1540.0                       684.44
#
#      productos_cantidad_referencia productos_unidad_medida_referencia  \
# 6                            500.0                                CM3
# 7                           2250.0                                CM3
# 52                          2250.0                                CM3
# 93                          1500.0                                CM3
# 130                         2250.0                                CM3
#
#      productos_precio_unitario_promo1  \
# 6                                 NaN
# 7                              1450.0
# 52                                NaN
# 93                                NaN
# 130                            1450.0
#
#                               productos_leyenda_promo1  \
# 6                                                  NaN
# 7    Promo A valida desde el 29/04/2025 hasta 06/05...
# 52                                                 NaN
# 93                                                 NaN
# 130  Promo A valida desde el 29/04/2025 hasta 06/05...
#
#      productos_precio_unitario_promo2  productos_leyenda_promo2  \
# 6                                 NaN                       NaN
# 7                                 NaN                       NaN
# 52                                NaN                       NaN
# 93                                NaN                       NaN
# 130                               NaN                       NaN
#
#      precio_zscore  id_bandera      sucursales_nombre sucursales_tipo  \
# 6         0.627199           2       Belgrano Cabildo    Supermercado
# 7        -0.178080           2  Martinez (Libertador)    Supermercado
# 52        0.327833           2       Villa Pueyrredon    Supermercado
# 93       -0.180417           3          E. Pérez 4566    Supermercado
# 130      -0.177266           2         San Nicolás II    Supermercado
#
#      sucursales_latitud  sucursales_longitud sucursales_barrio  \
# 6            -34.558821           -58.459349               NaN
# 7            -34.490270           -58.484964               NaN
# 52           -34.585933           -58.501809               NaN
# 93           -34.773098           -58.645218    Gonzalez Catan
# 130          -33.335962           -60.222474               NaN
#
#                 sucursales_localidad sucursales_provincia  \
# 6    Ciudad Autónoma de Buenos Aires                 CABA
# 7                           Martínez         Buenos Aires
# 52   Ciudad Autónoma de Buenos Aires                 CABA
# 93                        La Matanza         Buenos Aires
# 130                      San Nicolás         Buenos Aires
#
#     comercio_bandera_nombre                     localidad_provincia  \
# 6                    Market  Ciudad Autónoma de Buenos Aires - CABA
# 7                    Market                 Martínez - Buenos Aires
# 52                   Market  Ciudad Autónoma de Buenos Aires - CABA
# 93                  Express               La Matanza - Buenos Aires
# 130                  Market              San Nicolás - Buenos Aires
#
#      id_producto_code
# 6                6980
# 7                6259
# 52               4416
# 93               6993
# 130             10229
# <class 'pandas.core.frame.DataFrame'>
# Index: 12365 entries, 6 to 370585
# Data columns (total 27 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   id_sucursal                           12365 non-null  category
#  1   id_producto                           12365 non-null  category
#  2   productos_ean                         12365 non-null  bool
#  3   productos_descripcion                 12365 non-null  object
#  4   productos_cantidad_presentacion       12365 non-null  float64
#  5   productos_unidad_medida_presentacion  12365 non-null  category
#  6   productos_marca                       12365 non-null  category
#  7   productos_precio_lista                12365 non-null  float64
#  8   productos_precio_referencia           12365 non-null  float64
#  9   productos_cantidad_referencia         12365 non-null  float64
#  10  productos_unidad_medida_referencia    12365 non-null  category
#  11  productos_precio_unitario_promo1      394 non-null    float64
#  12  productos_leyenda_promo1              394 non-null    object
#  13  productos_precio_unitario_promo2      0 non-null      float64
#  14  productos_leyenda_promo2              0 non-null      float64
#  15  precio_zscore                         12365 non-null  float64
#  16  id_bandera                            12365 non-null  int64
#  17  sucursales_nombre                     12365 non-null  object
#  18  sucursales_tipo                       12365 non-null  object
#  19  sucursales_latitud                    12365 non-null  float64
#  20  sucursales_longitud                   12365 non-null  float64
#  21  sucursales_barrio                     2319 non-null   object
#  22  sucursales_localidad                  12365 non-null  object
#  23  sucursales_provincia                  12365 non-null  object
#  24  comercio_bandera_nombre               12365 non-null  category
#  25  localidad_provincia                   12365 non-null  object
#  26  id_producto_code                      12365 non-null  int16
# dtypes: bool(1), category(6), float64(10), int16(1), int64(1), object(8)
# memory usage: 2.4+ MB
# None

# %%
productos_df["id_producto"].nunique()
# Out:
# 313

# %%
productos_df["id_producto"].value_counts()
# Out:
# id_producto
# 7790639002423    77
# 7792799000097    77
# 7790895001000    77
# 7790639003819    77
# 7792931000015    76
#                  ..
# 7790580033507     0
# 7790580102517     0
# 7790580103361     0
# 7790580103385     0
# 9002490258313     0
# Name: count, Length: 11560, dtype: int64

# %% [markdown]
# De la ultima celda podemos analizar que hay productos que estan en TODAS las sucursales y que hay productos que no

# %% [markdown]
# Para tener un análisis acorde tomamos aquellos productos de bebidas no alcóholicas que están en los tres tipos de comercios.

# %%
# Contar el número de sucursales únicas por producto
productos_en_todas_sucursales = productos_df.groupby('id_producto')['comercio_bandera_nombre'].nunique()

# Filtrar los productos que están en todas los comercios, que en nuestro caso son 3, expres, hiper, market
productos_en_todas_sucursales = productos_en_todas_sucursales[productos_en_todas_sucursales == 3].index

# Filtrar el DataFrame original
productos_df_en_varias_sucursales = productos_df[productos_df['id_producto'].isin(productos_en_todas_sucursales)]
print(f"Cantidad de productos que estan en los 3 comercios: {productos_df_en_varias_sucursales['id_producto'].nunique()}")
# Out:
# Cantidad de productos que estan en los 3 comercios: 150
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_24415/3562760019.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   productos_en_todas_sucursales = productos_df.groupby('id_producto')['comercio_bandera_nombre'].nunique()

# %% [markdown]
# ### **Análisis de Outliers**

# %%
sns.boxplot(x='comercio_bandera_nombre', y='precio_zscore', hue='comercio_bandera_nombre', data=productos_df_en_varias_sucursales, palette=colores, legend=False)

plt.title('Boxplot de precios por Tipo de comercio')
plt.xlabel('Tipo de comercio')
plt.ylabel('Precio')
plt.show()

# %%
def remove_outliers_iqr(group):
    Q1 = group['precio_zscore'].quantile(0.25)
    Q3 = group['precio_zscore'].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return group[(group['precio_zscore'] >= lower) & (group['precio_zscore'] <= upper)]

# Aplica la función por categoría
productos_df_en_varias_sucursales = productos_df_en_varias_sucursales.groupby('comercio_bandera_nombre', group_keys=False).apply(remove_outliers_iqr)
# Out:
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_24415/1922502756.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   productos_df_en_varias_sucursales = productos_df_en_varias_sucursales.groupby('comercio_bandera_nombre', group_keys=False).apply(remove_outliers_iqr)
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_24415/1922502756.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   productos_df_en_varias_sucursales = productos_df_en_varias_sucursales.groupby('comercio_bandera_nombre', group_keys=False).apply(remove_outliers_iqr)

# %% [markdown]
# Volvemos a filtrar los productos que están en los 3 tipos de comercio ya que al eliminar outliers se pudo producir que algún producto no esté en todos estos tipos.

# %%
# Contar el número de sucursales únicas por producto
productos_en_todas_sucursales = productos_df_en_varias_sucursales.groupby('id_producto')['comercio_bandera_nombre'].nunique()

# Filtrar los productos que están en todas los comercios, que en nuestro caso son 3, expres, hiper, market
productos_en_todas_sucursales = productos_en_todas_sucursales[productos_en_todas_sucursales == 3].index

# Filtrar el DataFrame original
productos_df_en_varias_sucursales = productos_df_en_varias_sucursales[productos_df_en_varias_sucursales['id_producto'].isin(productos_en_todas_sucursales)]
print(f"Cantidad de productos que estan en los 3 comercios: {productos_df_en_varias_sucursales['id_producto'].nunique()}")
# Out:
# Cantidad de productos que estan en los 3 comercios: 146
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_24415/1613971439.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   productos_en_todas_sucursales = productos_df_en_varias_sucursales.groupby('id_producto')['comercio_bandera_nombre'].nunique()

# %%
sns.boxplot(x='comercio_bandera_nombre', y='precio_zscore', hue='comercio_bandera_nombre', data=productos_df_en_varias_sucursales, palette=colores, legend=False)

plt.title('Boxplot de precios por Tipo de comercio')
plt.xlabel('Tipo de comercio')
plt.ylabel('Precio')
plt.show()

# %% [markdown]
# ### **Análisis de precios máximos y mínimos**
#
# Analizamos el precio máximo y mínimo de cada producto agrupado por el tipo de comercio.

# %%
print("Cantidad de registros para cada tipo de comercio:")
print(productos_df_en_varias_sucursales['comercio_bandera_nombre'].value_counts())

# Agrupar por id_producto y comercio_bandera_nombre y calcular el máximo y mínimo de precio_zscore
resultado = productos_df_en_varias_sucursales.groupby(['id_producto_code', 'comercio_bandera_nombre'])['precio_zscore'].agg(['max', 'min']).reset_index()

resultado.head()
# Out:
# Cantidad de registros para cada tipo de comercio:
# comercio_bandera_nombre
# Market                    6067
# Express                   3282
# Hipermercado Carrefour     146
# Name: count, dtype: int64
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_24415/2361889854.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   resultado = productos_df_en_varias_sucursales.groupby(['id_producto_code', 'comercio_bandera_nombre'])['precio_zscore'].agg(['max', 'min']).reset_index()
#    id_producto_code comercio_bandera_nombre       max       min
# 0              3356                 Express  0.236332  0.236332
# 1              3356  Hipermercado Carrefour  0.236332  0.236332
# 2              3356                  Market  0.236332 -2.582358
# 3              3357                 Express  0.132475  0.132475
# 4              3357  Hipermercado Carrefour -0.953716 -0.953716

# %%
plt.figure(figsize=(30, 10))
sns.barplot(data=resultado, y='min', x='id_producto_code', hue='comercio_bandera_nombre', palette=colores)

plt.xticks(rotation=90)
plt.title("Precio mínimo de los productos")
plt.ylabel('Precio mínimo normalizado')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(30, 10))
sns.barplot(data=resultado, y='max', x='id_producto_code', hue='comercio_bandera_nombre', palette=colores)

plt.xticks(rotation=90)
plt.title("Precio máximo de los productos")
plt.ylabel('Precio máximo normalizado')
plt.tight_layout()
plt.show()

# %%
sns.kdeplot(data=resultado, x='min', hue='comercio_bandera_nombre', fill=True, palette=colores)
plt.xlabel('Precio mínimo normalizado')
plt.show()

# %%
sns.kdeplot(data=resultado, x='max', hue='comercio_bandera_nombre', fill=True, palette=colores)
plt.xlabel('Precio máximo normalizado')
plt.show()

# %%
promedios = productos_df_en_varias_sucursales.groupby('comercio_bandera_nombre')['precio_zscore'].mean().sort_values()
# Hacer el gráfico de barras
colores_barras = [colores[nombre] for nombre in promedios.index]
promedios.plot(kind='barh', color=colores_barras, figsize=(10, 6), alpha=0.7)
plt.xlabel('Promedio del z-score de precio')
plt.ylabel('Tipo de comercio')
plt.title('Promedio de precio normalizado por Tipo de comercio')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_24415/1158149480.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedios = productos_df_en_varias_sucursales.groupby('comercio_bandera_nombre')['precio_zscore'].mean().sort_values()
