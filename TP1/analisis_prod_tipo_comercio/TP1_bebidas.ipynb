# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Mostrar todas las columnas sin límite
pd.set_option('display.max_columns', None)

# %% [markdown]
# ##### **Precios de las bebidas no alcóholicas**
#
# Iniciamos analizando los precios de los productos de bebidas no alcóholicas dado que son un producto de consumo masivo presente en todo el territorio nacional.

# %%
colores = {
    'Express': 'orange',
    'Market': 'red',
    'Hipermercado Carrefour': 'blue',
}
productos_df = pd.read_csv('productos_procesado.zip', sep='|')

# Al leer el csv las columnas vuelven a ser sus tipos nativos entonces las reconvertimon a categóricas
productos_df['id_sucursal'] = productos_df['id_sucursal'].astype('category')
productos_df['id_producto'] = productos_df['id_producto'].astype('category')
productos_df['productos_unidad_medida_presentacion'] = productos_df['productos_unidad_medida_presentacion'].astype('category')
productos_df['productos_marca'] = productos_df['productos_marca'].astype('category')
productos_df['productos_unidad_medida_referencia'] = productos_df['productos_unidad_medida_referencia'].astype('category')
productos_df['comercio_bandera_nombre'] = productos_df['comercio_bandera_nombre'].astype('category')
productos_df['id_producto_code'] = productos_df['id_producto'].cat.codes

productos_df = productos_df[productos_df['productos_descripcion'].str.contains('^gaseosa|^agua', case=False, na=False)]
display(productos_df.head())
display(productos_df.info())
# Out:
#     id_sucursal    id_producto  productos_ean  \
# 14          120  7791813402022           True
# 15          209  7791720029978           True
# 125         258  7790895000997           True
# 182         217  7790895640490           True
# 207         477  7791813421603           True
#
#                                  productos_descripcion  \
# 14           AGUA SABORIZADA LIMON S GAS H2OH X 500 CC
# 15   GASEOSA LIGHT POMELO CARREFOUR CLASSIC PET X2....
# 125       GASEOSA COLA REGULAR COCA COLA PET X 2.25 LT
# 182   AGUA SABORIZADA POMELO SIN GAS AQUARIUS X 1.5 LT
# 207     AGUA SABORIZADA CITRUS C GAS H2OH PET X 1.5 LT
#
#      productos_cantidad_presentacion productos_unidad_medida_presentacion  \
# 14                               1.0                                  UNI
# 15                               1.0                                  UNI
# 125                              1.0                                  UNI
# 182                              1.0                                  UNI
# 207                              1.0                                  UNI
#
#        productos_marca  productos_precio_lista  productos_precio_referencia  \
# 14               H2OH!                  1400.0                      2800.00
# 15   CARREFOUR CLASSIC                  1540.0                       684.44
# 125          COCA COLA                  4200.0                      1866.67
# 182           AQUARIUS                  2100.0                      1400.00
# 207              H2OH!                  2159.0                      1439.33
#
#      productos_cantidad_referencia productos_unidad_medida_referencia  \
# 14                           500.0                                CM3
# 15                          2250.0                                CM3
# 125                         2250.0                                CM3
# 182                         1500.0                                CM3
# 207                         1500.0                                CM3
#
#      productos_precio_unitario_promo1  \
# 14                                NaN
# 15                             1450.0
# 125                               NaN
# 182                               NaN
# 207                               NaN
#
#                               productos_leyenda_promo1  \
# 14                                                 NaN
# 15   Promo A valida desde el 29/04/2025 hasta 06/05...
# 125                                                NaN
# 182                                                NaN
# 207                                                NaN
#
#      productos_precio_unitario_promo2  productos_leyenda_promo2  \
# 14                                NaN                       NaN
# 15                                NaN                       NaN
# 125                               NaN                       NaN
# 182                               NaN                       NaN
# 207                               NaN                       NaN
#
#      precio_zscore  id_bandera      sucursales_nombre sucursales_tipo  \
# 14        0.627199           2       Belgrano Cabildo    Supermercado
# 15       -0.178080           2  Martinez (Libertador)    Supermercado
# 125       0.327833           2       Villa Pueyrredon    Supermercado
# 182      -0.893930           1            Bella Vista    Hipermercado
# 207      -0.180417           3          E. Pérez 4566    Supermercado
#
#      sucursales_latitud  sucursales_longitud sucursales_barrio  \
# 14           -34.558821           -58.459349               NaN
# 15           -34.490270           -58.484964               NaN
# 125          -34.585933           -58.501809               NaN
# 182          -34.553106           -58.698256               NaN
# 207          -34.773098           -58.645218    Gonzalez Catan
#
#                 sucursales_localidad sucursales_provincia  \
# 14   Ciudad Autónoma de Buenos Aires                 CABA
# 15                          Martínez         Buenos Aires
# 125  Ciudad Autónoma de Buenos Aires                 CABA
# 182                       San Miguel         Buenos Aires
# 207                       La Matanza         Buenos Aires
#
#     comercio_bandera_nombre                     localidad_provincia  \
# 14                   Market  Ciudad Autónoma de Buenos Aires - CABA
# 15                   Market                 Martínez - Buenos Aires
# 125                  Market  Ciudad Autónoma de Buenos Aires - CABA
# 182  Hipermercado Carrefour               San Miguel - Buenos Aires
# 207                 Express               La Matanza - Buenos Aires
#
#      id_producto_code
# 14               8305
# 15               7532
# 125              5531
# 182              5621
# 207              8318
# <class 'pandas.core.frame.DataFrame'>
# Index: 22907 entries, 14 to 849185
# Data columns (total 27 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   id_sucursal                           22907 non-null  category
#  1   id_producto                           22907 non-null  category
#  2   productos_ean                         22907 non-null  bool
#  3   productos_descripcion                 22907 non-null  object
#  4   productos_cantidad_presentacion       22907 non-null  float64
#  5   productos_unidad_medida_presentacion  22907 non-null  category
#  6   productos_marca                       22907 non-null  category
#  7   productos_precio_lista                22907 non-null  float64
#  8   productos_precio_referencia           22907 non-null  float64
#  9   productos_cantidad_referencia         22907 non-null  float64
#  10  productos_unidad_medida_referencia    22907 non-null  category
#  11  productos_precio_unitario_promo1      809 non-null    float64
#  12  productos_leyenda_promo1              809 non-null    object
#  13  productos_precio_unitario_promo2      0 non-null      float64
#  14  productos_leyenda_promo2              0 non-null      float64
#  15  precio_zscore                         22907 non-null  float64
#  16  id_bandera                            22907 non-null  int64
#  17  sucursales_nombre                     22907 non-null  object
#  18  sucursales_tipo                       22907 non-null  object
#  19  sucursales_latitud                    22907 non-null  float64
#  20  sucursales_longitud                   22907 non-null  float64
#  21  sucursales_barrio                     2319 non-null   object
#  22  sucursales_localidad                  22907 non-null  object
#  23  sucursales_provincia                  22907 non-null  object
#  24  comercio_bandera_nombre               22907 non-null  category
#  25  localidad_provincia                   22907 non-null  object
#  26  id_producto_code                      22907 non-null  int16
# dtypes: bool(1), category(6), float64(10), int16(1), int64(1), object(8)
# memory usage: 4.4+ MB
# None

# %%
productos_df["id_producto"].nunique()
# Out:
# 318

# %%
productos_df["id_producto"].value_counts().loc[lambda x: x > 0]
# Out:
# id_producto
# 7792799000097    126
# 7790895001000    126
# 7790895000782    125
# 7798062547559    125
# 7791720037294    125
#                 ...
# 7790895006111      3
# 7791913001477      3
# 7791913005451      2
# 7793759320880      2
# 7798113302076      1
# Name: count, Length: 318, dtype: int64

# %% [markdown]
# De la última celda podemos analizar que hay productos que estan en todos los tipos de comercio y otros que no.

# %% [markdown]
# Para tener un análisis acorde tomamos aquellos productos de bebidas no alcóholicas que están en los tres tipos de comercios.

# %%
# Contar el número de sucursales únicas por producto
productos_en_todas_sucursales = productos_df.groupby('id_producto')['comercio_bandera_nombre'].nunique()

# Filtrar los productos que están en todas los comercios, que en nuestro caso son 3, expres, hiper, market
productos_en_todas_sucursales = productos_en_todas_sucursales[productos_en_todas_sucursales == 3].index

# Filtrar el DataFrame original
productos_df_en_varias_sucursales = productos_df[productos_df['id_producto'].isin(productos_en_todas_sucursales)]
print(f"Cantidad de productos que estan en los 3 comercios: {productos_df_en_varias_sucursales['id_producto'].nunique()}")
# Out:
# Cantidad de productos que estan en los 3 comercios: 176
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_48229/3562760019.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   productos_en_todas_sucursales = productos_df.groupby('id_producto')['comercio_bandera_nombre'].nunique()

# %% [markdown]
# ### **Análisis de Outliers**

# %%
sns.boxplot(x='comercio_bandera_nombre', y='precio_zscore', hue='comercio_bandera_nombre', data=productos_df_en_varias_sucursales, palette=colores, legend=False)

plt.title('Boxplot de precios por Tipo de comercio')
plt.xlabel('Tipo de comercio')
plt.ylabel('Precio')
plt.show()

# %%
def remove_outliers_iqr(group):
    Q1 = group['precio_zscore'].quantile(0.25)
    Q3 = group['precio_zscore'].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return group[(group['precio_zscore'] >= lower) & (group['precio_zscore'] <= upper)]

# Aplica la función por categoría
productos_df_en_varias_sucursales = productos_df_en_varias_sucursales.groupby('comercio_bandera_nombre', group_keys=False).apply(remove_outliers_iqr)
# Out:
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_48229/1922502756.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   productos_df_en_varias_sucursales = productos_df_en_varias_sucursales.groupby('comercio_bandera_nombre', group_keys=False).apply(remove_outliers_iqr)
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_48229/1922502756.py:10: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   productos_df_en_varias_sucursales = productos_df_en_varias_sucursales.groupby('comercio_bandera_nombre', group_keys=False).apply(remove_outliers_iqr)

# %% [markdown]
# Volvemos a filtrar los productos que están en los 3 tipos de comercio ya que al eliminar outliers se pudo producir que algún producto no esté en todos estos tipos.

# %%
# Contar el número de sucursales únicas por producto
productos_en_todas_sucursales = productos_df_en_varias_sucursales.groupby('id_producto')['comercio_bandera_nombre'].nunique()

# Filtrar los productos que están en todas los comercios, que en nuestro caso son 3, expres, hiper, market
productos_en_todas_sucursales = productos_en_todas_sucursales[productos_en_todas_sucursales == 3].index

# Filtrar el DataFrame original
productos_df_en_varias_sucursales = productos_df_en_varias_sucursales[productos_df_en_varias_sucursales['id_producto'].isin(productos_en_todas_sucursales)]
print(f"Cantidad de productos que estan en los 3 comercios: {productos_df_en_varias_sucursales['id_producto'].nunique()}")
# Out:
# Cantidad de productos que estan en los 3 comercios: 171
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_48229/1613971439.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   productos_en_todas_sucursales = productos_df_en_varias_sucursales.groupby('id_producto')['comercio_bandera_nombre'].nunique()

# %%
sns.boxplot(x='comercio_bandera_nombre', y='precio_zscore', hue='comercio_bandera_nombre', data=productos_df_en_varias_sucursales, palette=colores, legend=False)

plt.title('Boxplot de precios por Tipo de comercio')
plt.xlabel('Tipo de comercio')
plt.ylabel('Precio')
plt.show()

# %% [markdown]
# ### **Análisis de precios máximos y mínimos**
#
# Analizamos el precio máximo y mínimo de cada producto agrupado por el tipo de comercio.

# %%
print("Cantidad de registros para cada tipo de comercio:")
print(productos_df_en_varias_sucursales['comercio_bandera_nombre'].value_counts())

# Agrupar por id_producto y comercio_bandera_nombre y calcular el máximo y mínimo de precio_zscore
resultado = productos_df_en_varias_sucursales.groupby(['id_producto_code', 'comercio_bandera_nombre'])['precio_zscore'].agg(['max', 'min']).reset_index()

resultado.head()
# Out:
# Cantidad de registros para cada tipo de comercio:
# comercio_bandera_nombre
# Market                    7537
# Hipermercado Carrefour    6295
# Express                   3630
# Name: count, dtype: int64
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_48229/2361889854.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   resultado = productos_df_en_varias_sucursales.groupby(['id_producto_code', 'comercio_bandera_nombre'])['precio_zscore'].agg(['max', 'min']).reset_index()
#    id_producto_code comercio_bandera_nombre       max       min
# 0              4271                 Express  0.236332  0.236332
# 1              4271  Hipermercado Carrefour  0.236332 -2.582358
# 2              4271                  Market  0.236332 -2.582358
# 3              4272                 Express  0.132475  0.132475
# 4              4272  Hipermercado Carrefour -0.953716 -0.953716

# %%
plt.figure(figsize=(30, 10))
sns.barplot(data=resultado, y='min', x='id_producto_code', hue='comercio_bandera_nombre', palette=colores)

plt.xticks(rotation=90)
plt.title("Precio mínimo de los productos")
plt.ylabel('Precio mínimo normalizado')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(30, 10))
sns.barplot(data=resultado, y='max', x='id_producto_code', hue='comercio_bandera_nombre', palette=colores)

plt.xticks(rotation=90)
plt.title("Precio máximo de los productos")
plt.ylabel('Precio máximo normalizado')
plt.tight_layout()
plt.show()

# %%
sns.kdeplot(data=resultado, x='min', hue='comercio_bandera_nombre', fill=True, palette=colores)
plt.xlabel('Precio mínimo normalizado')
plt.show()

# %%
sns.kdeplot(data=resultado, x='max', hue='comercio_bandera_nombre', fill=True, palette=colores)
plt.xlabel('Precio máximo normalizado')
plt.show()

# %%
promedios = productos_df_en_varias_sucursales.groupby('comercio_bandera_nombre')['precio_zscore'].mean().sort_values()
# Hacer el gráfico de barras
colores_barras = [colores[nombre] for nombre in promedios.index]
promedios.plot(kind='barh', color=colores_barras, figsize=(10, 6), alpha=0.7)
plt.xlabel('Promedio del z-score de precio')
plt.ylabel('Tipo de comercio')
plt.title('Promedio de precio normalizado por Tipo de comercio')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/gf/xjt2z0l14fn8dy1y22cnhzm40000gn/T/ipykernel_48229/1158149480.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   promedios = productos_df_en_varias_sucursales.groupby('comercio_bandera_nombre')['precio_zscore'].mean().sort_values()

# %% [markdown]
# Analizando los gráficos anteriores se puede concluir que los precios más bajos se encuentran en el tipo de comercio Hipermercado Carrefour. En cambio los más altos se encuentran en el tipo de comercio Express.
